# %%
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/data/audio_test.h5"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/data/audio_train.h5"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/data/text_test_emb.h5"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/data/text_train_emb.h5"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/data/video_test.h5"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/data/video_train.h5"

# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Test_labels_2class.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Test_labels_5class.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Test_labels_7class.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Test_labels_angry.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Test_labels_disgust.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Test_labels_fear.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Test_labels_happy.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Test_labels_sad.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Test_labels_surprise.csv"

# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Train_labels_2class.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Train_labels_5class.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Train_labels_7class.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Train_labels_angry.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Train_labels_disgust.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Train_labels_fear.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Train_labels_happy.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Train_labels_sad.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Train_labels_surprise.csv"
# Out:
# --2019-07-26 09:58:30--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/data/audio_test.h5
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 57213024 (55M)
# Saving to: ‘audio_test.h5.2’
#
# audio_test.h5.2     100%[===================>]  54.56M  10.9MB/s    in 5.6s
#
# 2019-07-26 09:58:36 (9.75 MB/s) - ‘audio_test.h5.2’ saved [57213024/57213024]
#
# --2019-07-26 09:58:40--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/data/audio_train.h5
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 181035744 (173M)
# Saving to: ‘audio_train.h5.2’
#
# audio_train.h5.2    100%[===================>] 172.65M  10.9MB/s    in 17s
#
# 2019-07-26 09:58:56 (10.4 MB/s) - ‘audio_train.h5.2’ saved [181035744/181035744]
#
# --2019-07-26 09:58:58--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/data/text_test_emb.h5
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 231938144 (221M)
# Saving to: ‘text_test_emb.h5.2’
#
# text_test_emb.h5.2  100%[===================>] 221.19M  10.9MB/s    in 21s
#
# 2019-07-26 09:59:20 (10.4 MB/s) - ‘text_test_emb.h5.2’ saved [231938144/231938144]
#
# --2019-07-26 09:59:23--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/data/text_train_emb.h5
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 733922144 (700M)
# Saving to: ‘text_train_emb.h5.2’
#
# text_train_emb.h5.2 100%[===================>] 699.92M  10.8MB/s    in 66s
#
# 2019-07-26 10:00:29 (10.6 MB/s) - ‘text_train_emb.h5.2’ saved [733922144/733922144]
#
# --2019-07-26 10:00:32--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/data/video_test.h5
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 27061344 (26M)
# Saving to: ‘video_test.h5.2’
#
# video_test.h5.2     100%[===================>]  25.81M  8.89MB/s    in 2.9s
#
# 2019-07-26 10:00:36 (8.89 MB/s) - ‘video_test.h5.2’ saved [27061344/27061344]
#
# --2019-07-26 10:00:38--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/data/video_train.h5
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 85626144 (82M)
# Saving to: ‘video_train.h5.2’
#
# video_train.h5.2    100%[===================>]  81.66M  10.5MB/s    in 8.3s
#
# 2019-07-26 10:00:46 (9.81 MB/s) - ‘video_train.h5.2’ saved [85626144/85626144]
#
# --2019-07-26 10:00:49--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Test_labels_2class.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9664 (9.4K) [text/csv]
# Saving to: ‘mosi2uni_Test_labels_2class.csv.2’
#
# mosi2uni_Test_label 100%[===================>]   9.44K  --.-KB/s    in 0s
#
# 2019-07-26 10:00:49 (23.9 MB/s) - ‘mosi2uni_Test_labels_2class.csv.2’ saved [9664/9664]
#
# --2019-07-26 10:00:52--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Test_labels_5class.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9664 (9.4K) [text/csv]
# Saving to: ‘mosi2uni_Test_labels_5class.csv.2’
#
# mosi2uni_Test_label 100%[===================>]   9.44K  --.-KB/s    in 0s
#
# 2019-07-26 10:00:52 (27.3 MB/s) - ‘mosi2uni_Test_labels_5class.csv.2’ saved [9664/9664]
#
# --2019-07-26 10:00:56--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Test_labels_7class.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9664 (9.4K) [text/csv]
# Saving to: ‘mosi2uni_Test_labels_7class.csv.2’
#
# mosi2uni_Test_label 100%[===================>]   9.44K  --.-KB/s    in 0s
#
# 2019-07-26 10:00:56 (36.4 MB/s) - ‘mosi2uni_Test_labels_7class.csv.2’ saved [9664/9664]
#
# --2019-07-26 10:00:59--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Test_labels_angry.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9664 (9.4K) [text/csv]
# Saving to: ‘mosi2uni_Test_labels_angry.csv.2’
#
# mosi2uni_Test_label 100%[===================>]   9.44K  --.-KB/s    in 0s
#
# 2019-07-26 10:00:59 (24.7 MB/s) - ‘mosi2uni_Test_labels_angry.csv.2’ saved [9664/9664]
#
# --2019-07-26 10:01:02--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Test_labels_disgust.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9664 (9.4K) [text/csv]
# Saving to: ‘mosi2uni_Test_labels_disgust.csv.2’
#
# mosi2uni_Test_label 100%[===================>]   9.44K  --.-KB/s    in 0s
#
# 2019-07-26 10:01:02 (31.7 MB/s) - ‘mosi2uni_Test_labels_disgust.csv.2’ saved [9664/9664]
#
# --2019-07-26 10:01:07--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Test_labels_fear.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9664 (9.4K) [text/csv]
# Saving to: ‘mosi2uni_Test_labels_fear.csv.2’
#
# mosi2uni_Test_label 100%[===================>]   9.44K  --.-KB/s    in 0.001s
#
# 2019-07-26 10:01:07 (17.1 MB/s) - ‘mosi2uni_Test_labels_fear.csv.2’ saved [9664/9664]
#
# --2019-07-26 10:01:09--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Test_labels_happy.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9664 (9.4K) [text/csv]
# Saving to: ‘mosi2uni_Test_labels_happy.csv.2’
#
# mosi2uni_Test_label 100%[===================>]   9.44K  --.-KB/s    in 0s
#
# 2019-07-26 10:01:10 (20.2 MB/s) - ‘mosi2uni_Test_labels_happy.csv.2’ saved [9664/9664]
#
# --2019-07-26 10:01:13--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Test_labels_sad.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9664 (9.4K) [text/csv]
# Saving to: ‘mosi2uni_Test_labels_sad.csv.2’
#
# mosi2uni_Test_label 100%[===================>]   9.44K  --.-KB/s    in 0s
#
# 2019-07-26 10:01:13 (41.0 MB/s) - ‘mosi2uni_Test_labels_sad.csv.2’ saved [9664/9664]
#
# --2019-07-26 10:01:17--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Test_labels_surprise.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9664 (9.4K) [text/csv]
# Saving to: ‘mosi2uni_Test_labels_surprise.csv.2’
#
# mosi2uni_Test_label 100%[===================>]   9.44K  --.-KB/s    in 0s
#
# 2019-07-26 10:01:17 (31.1 MB/s) - ‘mosi2uni_Test_labels_surprise.csv.2’ saved [9664/9664]
#
# --2019-07-26 10:01:20--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Train_labels_2class.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 30580 (30K) [text/csv]
# Saving to: ‘mosi2uni_Train_labels_2class.csv.2’
#
# mosi2uni_Train_labe 100%[===================>]  29.86K  --.-KB/s    in 0.1s
#
# 2019-07-26 10:01:20 (304 KB/s) - ‘mosi2uni_Train_labels_2class.csv.2’ saved [30580/30580]
#
# --2019-07-26 10:01:24--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Train_labels_5class.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 30580 (30K) [text/csv]
# Saving to: ‘mosi2uni_Train_labels_5class.csv.2’
#
# mosi2uni_Train_labe 100%[===================>]  29.86K  --.-KB/s    in 0.1s
#
# 2019-07-26 10:01:24 (303 KB/s) - ‘mosi2uni_Train_labels_5class.csv.2’ saved [30580/30580]
#
# --2019-07-26 10:01:28--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Train_labels_7class.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 30580 (30K) [text/csv]
# Saving to: ‘mosi2uni_Train_labels_7class.csv.2’
#
# mosi2uni_Train_labe 100%[===================>]  29.86K  --.-KB/s    in 0.1s
#
# 2019-07-26 10:01:28 (305 KB/s) - ‘mosi2uni_Train_labels_7class.csv.2’ saved [30580/30580]
#
# --2019-07-26 10:01:31--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Train_labels_angry.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 30580 (30K) [text/csv]
# Saving to: ‘mosi2uni_Train_labels_angry.csv.2’
#
# mosi2uni_Train_labe 100%[===================>]  29.86K  --.-KB/s    in 0.1s
#
# 2019-07-26 10:01:31 (305 KB/s) - ‘mosi2uni_Train_labels_angry.csv.2’ saved [30580/30580]
#
# --2019-07-26 10:01:34--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Train_labels_disgust.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 30580 (30K) [text/csv]
# Saving to: ‘mosi2uni_Train_labels_disgust.csv.2’
#
# mosi2uni_Train_labe 100%[===================>]  29.86K  --.-KB/s    in 0.1s
#
# 2019-07-26 10:01:34 (304 KB/s) - ‘mosi2uni_Train_labels_disgust.csv.2’ saved [30580/30580]
#
# --2019-07-26 10:01:37--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Train_labels_fear.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 30580 (30K) [text/csv]
# Saving to: ‘mosi2uni_Train_labels_fear.csv.2’
#
# mosi2uni_Train_labe 100%[===================>]  29.86K  --.-KB/s    in 0.1s
#
# 2019-07-26 10:01:37 (304 KB/s) - ‘mosi2uni_Train_labels_fear.csv.2’ saved [30580/30580]
#
# --2019-07-26 10:01:40--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Train_labels_happy.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 30580 (30K) [text/csv]
# Saving to: ‘mosi2uni_Train_labels_happy.csv.2’
#
# mosi2uni_Train_labe 100%[===================>]  29.86K  --.-KB/s    in 0.1s
#
# 2019-07-26 10:01:41 (304 KB/s) - ‘mosi2uni_Train_labels_happy.csv.2’ saved [30580/30580]
#
# --2019-07-26 10:01:44--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Train_labels_sad.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 30580 (30K) [text/csv]
# Saving to: ‘mosi2uni_Train_labels_sad.csv.2’
#
# mosi2uni_Train_labe 100%[===================>]  29.86K  --.-KB/s    in 0.1s
#
# 2019-07-26 10:01:44 (304 KB/s) - ‘mosi2uni_Train_labels_sad.csv.2’ saved [30580/30580]
#
# --2019-07-26 10:01:48--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Train_labels_surprise.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 30580 (30K) [text/csv]
# Saving to: ‘mosi2uni_Train_labels_surprise.csv.2’
#
# mosi2uni_Train_labe 100%[===================>]  29.86K  --.-KB/s    in 0.1s
#
# 2019-07-26 10:01:48 (305 KB/s) - ‘mosi2uni_Train_labels_surprise.csv.2’ saved [30580/30580]

# %%
import pandas as pd
import numpy as np
import h5py
from sklearn.metrics import classification_report
from keras.models import load_model
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import *
from sklearn.utils.multiclass import unique_labels
import keras
import tensorflow as tf
from time import time
import scipy
from keras import layers
from google.colab import files	
from sklearn.utils import class_weight
from keras.models import load_model
from keras.models import Model,Sequential,Model
from keras.layers import *
from keras.callbacks import TensorBoard
from keras import callbacks
from keras.callbacks import *
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
import pandas as pd
import numpy as np
import h5py

Test_labels_fear = np.array(pd.read_csv("mosi2uni_Test_labels_fear.csv",header=None))
Train_labels_fear = np.array(pd.read_csv("mosi2uni_Train_labels_fear.csv",header=None))

Test_labels_happy = np.array(pd.read_csv("mosi2uni_Test_labels_happy.csv",header=None))
Train_labels_happy = np.array(pd.read_csv("mosi2uni_Train_labels_happy.csv",header=None))

Test_labels_sad = np.array(pd.read_csv("mosi2uni_Test_labels_sad.csv",header=None))
Train_labels_sad = np.array(pd.read_csv("mosi2uni_Train_labels_sad.csv",header=None))

Test_labels_disgust = np.array(pd.read_csv("mosi2uni_Test_labels_disgust.csv",header=None))
Train_labels_disgust = np.array(pd.read_csv("mosi2uni_Train_labels_disgust.csv",header=None))

Test_labels_surprise = np.array(pd.read_csv("mosi2uni_Test_labels_surprise.csv",header=None))
Train_labels_surprise = np.array(pd.read_csv("mosi2uni_Train_labels_surprise.csv",header=None))

Test_labels_angry = np.array(pd.read_csv("mosi2uni_Test_labels_angry.csv",header=None))
Train_labels_angry = np.array(pd.read_csv("mosi2uni_Train_labels_angry.csv",header=None))

train_video = h5py.File("video_train.h5","r")
train_video = np.array(train_video.get('d1'))
test_video = h5py.File("video_test.h5","r")
test_video = np.array(test_video.get('d1'))

train_audio = h5py.File("audio_train.h5","r")
train_audio = np.array(train_audio.get('d1'))
test_audio = h5py.File("audio_test.h5","r")
test_audio = np.array(test_audio.get('d1'))

train_text = h5py.File("text_train_emb.h5","r")
train_text = np.array(train_text.get('d1'))
test_text = h5py.File("text_test_emb.h5","r")
test_text = np.array(test_text.get('d1'))

# %%
train_concat = np.concatenate([train_video,train_audio,train_text],axis=-1)
test_concat = np.concatenate([test_video,test_audio,test_text],axis=-1)

# %%
from sklearn.utils import class_weight
class_weight = class_weight.compute_class_weight('balanced',np.unique(Train_labels_happy.squeeze()),Train_labels_happy.squeeze())
print(class_weight)

i = Input(shape=(20,409))
x = LSTM(128,return_sequences = True)(i)
x = LSTM(64,return_sequences = True)(x)
x = LSTM(32,return_sequences = False)(x)
x = Dense(32,activation='relu')(x)
x = Dense(1,activation='sigmoid')(x)

model = Model(i,x)
print(model.summary())
model.compile('adam','binary_crossentropy',metrics=['accuracy'])

es = EarlyStopping(monitor='val_acc',mode='max' ,patience=5, min_delta=0.0001,verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_acc', factor=0.2,patience=2,min_lr=0.00001)
model.fit(train_concat,Train_labels_happy,512,epochs=100,validation_split=0.1,callbacks=[es,reduce_lr],
         class_weight=dict(enumerate(class_weight)))


y_pred = (model.predict(test_concat)>0.5).astype("float")
y_true = Test_labels_happy
cm = confusion_matrix(y_true,y_pred)

p = precision_score(y_true,y_pred)
a = accuracy_score(y_true,y_pred)
r = recall_score(y_true,y_pred)
f = f1_score(y_true,y_pred)
print(cm)
print("accuracy  :",a)
print("f1 score  :",f)
print("precision :",p)
print("recall    :",r)


TP = cm[1][1]
TN = cm[0][0]
P = Test_labels_happy.sum()
N = 4832-P
wa = ((TP*N/P) + TN)/(0.02*N)
print("WA        :",wa)
print(classification_report(y_true,y_pred))
model.save("EF_CW_happy.h5")
# Out:
# [1.07027859 0.93838223]
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 20, 409)           0
# _________________________________________________________________
# lstm_7 (LSTM)                (None, 20, 128)           275456
# _________________________________________________________________
# lstm_8 (LSTM)                (None, 20, 64)            49408
# _________________________________________________________________
# lstm_9 (LSTM)                (None, 32)                12416
# _________________________________________________________________
# dense_5 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 338,369
# Trainable params: 338,369
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 13761 samples, validate on 1529 samples
# Epoch 1/100
# 13761/13761 [==============================] - 8s 562us/step - loss: 0.6545 - acc: 0.6235 - val_loss: 0.6722 - val_acc: 0.5886
# Epoch 2/100
# 13761/13761 [==============================] - 5s 361us/step - loss: 0.6261 - acc: 0.6505 - val_loss: 0.6557 - val_acc: 0.6056
# Epoch 3/100
# 13761/13761 [==============================] - 5s 360us/step - loss: 0.6087 - acc: 0.6704 - val_loss: 0.6523 - val_acc: 0.6194
# Epoch 4/100
# 13761/13761 [==============================] - 5s 361us/step - loss: 0.5950 - acc: 0.6816 - val_loss: 0.6429 - val_acc: 0.6167
# Epoch 5/100
# 13761/13761 [==============================] - 5s 363us/step - loss: 0.5769 - acc: 0.6957 - val_loss: 0.6588 - val_acc: 0.6331
# Epoch 6/100
# 13761/13761 [==============================] - 5s 363us/step - loss: 0.5623 - acc: 0.7071 - val_loss: 0.6502 - val_acc: 0.6024
# Epoch 7/100
# 13761/13761 [==============================] - 5s 364us/step - loss: 0.5502 - acc: 0.7172 - val_loss: 0.6526 - val_acc: 0.6207
# Epoch 8/100
# 13761/13761 [==============================] - 5s 361us/step - loss: 0.5196 - acc: 0.7405 - val_loss: 0.6553 - val_acc: 0.6305
# Epoch 9/100
# 13761/13761 [==============================] - 5s 360us/step - loss: 0.5079 - acc: 0.7459 - val_loss: 0.6785 - val_acc: 0.6279
# Epoch 10/100
# 13761/13761 [==============================] - 5s 359us/step - loss: 0.4972 - acc: 0.7564 - val_loss: 0.6779 - val_acc: 0.6246
# Epoch 00010: early stopping
# [[1740  570]
#  [1020 1502]]
# accuracy  : 0.6709437086092715
# f1 score  : 0.6538963865912059
# precision : 0.724903474903475
# recall    : 0.5955590800951626
# WA        : 67.44029166709578
#               precision    recall  f1-score   support
#
#            0       0.63      0.75      0.69      2310
#            1       0.72      0.60      0.65      2522
#
#     accuracy                           0.67      4832
#    macro avg       0.68      0.67      0.67      4832
# weighted avg       0.68      0.67      0.67      4832

# %%
from sklearn.utils import class_weight
class_weight = class_weight.compute_class_weight('balanced',np.unique(Train_labels_angry.squeeze()),Train_labels_angry.squeeze())
print(class_weight)

i = Input(shape=(20,409))
x = LSTM(128,return_sequences = True)(i)
x = LSTM(64,return_sequences = True)(x)
x = LSTM(32,return_sequences = False)(x)
x = Dense(32,activation='relu')(x)
x = Dense(1,activation='sigmoid')(x)

model = Model(i,x)
print(model.summary())
model.compile('adam','binary_crossentropy',metrics=['accuracy'])

es = EarlyStopping(monitor='val_acc',mode='max' ,patience=5, min_delta=0.0001,verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_acc', factor=0.2,patience=2,min_lr=0.00001)
model.fit(train_concat,Train_labels_angry,512,epochs=100,validation_split=0.1,callbacks=[es,reduce_lr],
         class_weight=dict(enumerate(class_weight)))


y_pred = (model.predict(test_concat)>0.5).astype("float")
y_true = Test_labels_angry
cm = confusion_matrix(y_true,y_pred)

p = precision_score(y_true,y_pred)
a = accuracy_score(y_true,y_pred)
r = recall_score(y_true,y_pred)
f = f1_score(y_true,y_pred)
print(cm)
print("accuracy  :",a)
print("f1 score  :",f)
print("precision :",p)
print("recall    :",r)


TP = cm[1][1]
TN = cm[0][0]
P = Test_labels_angry.sum()
N = 4832-P
wa = ((TP*N/P) + TN)/(0.02*N)
print("WA        :",wa)
print(classification_report(y_true,y_pred))
model.save("EF_CW_angry.h5")
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0726 10:09:31.255839 139856615974784 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0726 10:09:31.272161 139856615974784 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0726 10:09:31.276532 139856615974784 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
# [0.64531105 2.22044728]
# W0726 10:09:31.980291 139856615974784 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0726 10:09:32.003574 139856615974784 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3376: The name tf.log is deprecated. Please use tf.math.log instead.
#
# W0726 10:09:32.009318 139856615974784 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 20, 409)           0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 20, 128)           275456
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 20, 64)            49408
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 32)                12416
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 338,369
# Trainable params: 338,369
# Non-trainable params: 0
# _________________________________________________________________
# None
# W0726 10:09:34.561602 139856615974784 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
# Train on 13761 samples, validate on 1529 samples
# Epoch 1/100
# 13761/13761 [==============================] - 8s 557us/step - loss: 0.6696 - acc: 0.6534 - val_loss: 0.6354 - val_acc: 0.6612
# Epoch 2/100
# 13761/13761 [==============================] - 5s 365us/step - loss: 0.6480 - acc: 0.6262 - val_loss: 0.6255 - val_acc: 0.6370
# Epoch 3/100
# 13761/13761 [==============================] - 5s 363us/step - loss: 0.6272 - acc: 0.6388 - val_loss: 0.6446 - val_acc: 0.6638
# Epoch 4/100
# 13761/13761 [==============================] - 5s 365us/step - loss: 0.6156 - acc: 0.6542 - val_loss: 0.6142 - val_acc: 0.6521
# Epoch 5/100
# 13761/13761 [==============================] - 5s 363us/step - loss: 0.5981 - acc: 0.6679 - val_loss: 0.6281 - val_acc: 0.6213
# Epoch 6/100
# 13761/13761 [==============================] - 5s 364us/step - loss: 0.5732 - acc: 0.6763 - val_loss: 0.6261 - val_acc: 0.6344
# Epoch 7/100
# 13761/13761 [==============================] - 5s 366us/step - loss: 0.5592 - acc: 0.6958 - val_loss: 0.6316 - val_acc: 0.6167
# Epoch 8/100
# 13761/13761 [==============================] - 5s 364us/step - loss: 0.5478 - acc: 0.7027 - val_loss: 0.6360 - val_acc: 0.6226
# Epoch 00008: early stopping
# [[2400 1461]
#  [ 284  687]]
# accuracy  : 0.6388658940397351
# f1 score  : 0.4405258095543444
# precision : 0.3198324022346369
# recall    : 0.7075180226570545
# WA        : 66.45593221288381
#               precision    recall  f1-score   support
#
#            0       0.89      0.62      0.73      3861
#            1       0.32      0.71      0.44       971
#
#     accuracy                           0.64      4832
#    macro avg       0.61      0.66      0.59      4832
# weighted avg       0.78      0.64      0.67      4832

# %%
from sklearn.utils import class_weight
class_weight = class_weight.compute_class_weight('balanced',np.unique(Train_labels_sad.squeeze()),Train_labels_sad.squeeze())
print(class_weight)

i = Input(shape=(20,409))
x = LSTM(128,return_sequences = True)(i)
x = LSTM(64,return_sequences = True)(x)
x = LSTM(32,return_sequences = False)(x)
x = Dense(32,activation='relu')(x)
x = Dense(1,activation='sigmoid')(x)

model = Model(i,x)
print(model.summary())
model.compile('adam','binary_crossentropy',metrics=['accuracy'])

es = EarlyStopping(monitor='val_acc',mode='max' ,patience=5, min_delta=0.0001,verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_acc', factor=0.2,patience=2,min_lr=0.00001)
model.fit(train_concat,Train_labels_sad,512,epochs=100,validation_split=0.1,callbacks=[es,reduce_lr],
         class_weight=dict(enumerate(class_weight)))


y_pred = (model.predict(test_concat)>0.5).astype("float")
y_true = Test_labels_sad
cm = confusion_matrix(y_true,y_pred)

p = precision_score(y_true,y_pred)
a = accuracy_score(y_true,y_pred)
r = recall_score(y_true,y_pred)
f = f1_score(y_true,y_pred)
print(cm)
print("accuracy  :",a)
print("f1 score  :",f)
print("precision :",p)
print("recall    :",r)


TP = cm[1][1]
TN = cm[0][0]
P = Test_labels_sad.sum()
N = 4832-P
wa = ((TP*N/P) + TN)/(0.02*N)
print("WA        :",wa)
print(classification_report(y_true,y_pred))
model.save("EF_CW_sad.h5")
# Out:
# [0.67155657 1.95724526]
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         (None, 20, 409)           0
# _________________________________________________________________
# lstm_10 (LSTM)               (None, 20, 128)           275456
# _________________________________________________________________
# lstm_11 (LSTM)               (None, 20, 64)            49408
# _________________________________________________________________
# lstm_12 (LSTM)               (None, 32)                12416
# _________________________________________________________________
# dense_7 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 338,369
# Trainable params: 338,369
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 13761 samples, validate on 1529 samples
# Epoch 1/100
# 13761/13761 [==============================] - 8s 599us/step - loss: 0.6808 - acc: 0.6022 - val_loss: 0.6505 - val_acc: 0.5167
# Epoch 2/100
# 13761/13761 [==============================] - 5s 364us/step - loss: 0.6633 - acc: 0.5587 - val_loss: 0.6547 - val_acc: 0.4742
# Epoch 3/100
# 13761/13761 [==============================] - 5s 367us/step - loss: 0.6546 - acc: 0.5735 - val_loss: 0.6483 - val_acc: 0.5088
# Epoch 4/100
# 13761/13761 [==============================] - 5s 366us/step - loss: 0.6404 - acc: 0.5896 - val_loss: 0.6387 - val_acc: 0.6030
# Epoch 5/100
# 13761/13761 [==============================] - 5s 365us/step - loss: 0.6311 - acc: 0.6048 - val_loss: 0.6471 - val_acc: 0.5612
# Epoch 6/100
# 13761/13761 [==============================] - 5s 366us/step - loss: 0.6245 - acc: 0.6040 - val_loss: 0.6459 - val_acc: 0.5867
# Epoch 7/100
# 13761/13761 [==============================] - 5s 365us/step - loss: 0.6177 - acc: 0.6211 - val_loss: 0.6485 - val_acc: 0.5729
# Epoch 8/100
# 13761/13761 [==============================] - 5s 366us/step - loss: 0.6151 - acc: 0.6196 - val_loss: 0.6488 - val_acc: 0.5729
# Epoch 9/100
# 13761/13761 [==============================] - 5s 366us/step - loss: 0.6136 - acc: 0.6226 - val_loss: 0.6491 - val_acc: 0.5749
# Epoch 00009: early stopping
# [[1857 1641]
#  [ 370  964]]
# accuracy  : 0.5838162251655629
# f1 score  : 0.48946433104848946
# precision : 0.37005758157389634
# recall    : 0.7226386806596702
# WA        : 62.67567331257183
#               precision    recall  f1-score   support
#
#            0       0.83      0.53      0.65      3498
#            1       0.37      0.72      0.49      1334
#
#     accuracy                           0.58      4832
#    macro avg       0.60      0.63      0.57      4832
# weighted avg       0.71      0.58      0.60      4832

# %%
from sklearn.utils import class_weight
class_weight = class_weight.compute_class_weight('balanced',np.unique(Train_labels_fear.squeeze()),Train_labels_fear.squeeze())
print(class_weight)

i = Input(shape=(20,409))
x = LSTM(128,return_sequences = True)(i)
x = LSTM(64,return_sequences = True)(x)
x = LSTM(32,return_sequences = False)(x)
x = Dense(32,activation='relu')(x)
x = Dense(1,activation='sigmoid')(x)

model = Model(i,x)
print(model.summary())
model.compile('adam','binary_crossentropy',metrics=['accuracy'])

es = EarlyStopping(monitor='val_acc',mode='max' ,patience=5, min_delta=0.0001,verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_acc', factor=0.2,patience=2,min_lr=0.00001)
model.fit(train_concat,Train_labels_fear,512,epochs=100,validation_split=0.1,callbacks=[es,reduce_lr],
         class_weight=dict(enumerate(class_weight)))


y_pred = (model.predict(test_concat)>0.5).astype("float")
y_true = Test_labels_fear
cm = confusion_matrix(y_true,y_pred)

p = precision_score(y_true,y_pred)
a = accuracy_score(y_true,y_pred)
r = recall_score(y_true,y_pred)
f = f1_score(y_true,y_pred)
print(cm)
print("accuracy  :",a)
print("f1 score  :",f)
print("precision :",p)
print("recall    :",r)


TP = cm[1][1]
TN = cm[0][0]
P = Test_labels_fear.sum()
N = 4832-P
wa = ((TP*N/P) + TN)/(0.02*N)
print("WA        :",wa)
print(classification_report(y_true,y_pred))
model.save("EF_CW_fear.h5")
# Out:
# [0.54720492 5.79605762]
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         (None, 20, 409)           0
# _________________________________________________________________
# lstm_13 (LSTM)               (None, 20, 128)           275456
# _________________________________________________________________
# lstm_14 (LSTM)               (None, 20, 64)            49408
# _________________________________________________________________
# lstm_15 (LSTM)               (None, 32)                12416
# _________________________________________________________________
# dense_9 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 338,369
# Trainable params: 338,369
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 13761 samples, validate on 1529 samples
# Epoch 1/100
# 13761/13761 [==============================] - 9s 671us/step - loss: 0.6596 - acc: 0.4202 - val_loss: 0.7167 - val_acc: 0.5677
# Epoch 2/100
# 13761/13761 [==============================] - 5s 366us/step - loss: 0.6404 - acc: 0.5371 - val_loss: 0.7358 - val_acc: 0.3290
# Epoch 3/100
# 13761/13761 [==============================] - 5s 367us/step - loss: 0.6271 - acc: 0.4929 - val_loss: 0.7574 - val_acc: 0.5075
# Epoch 4/100
# 13761/13761 [==============================] - 5s 370us/step - loss: 0.6050 - acc: 0.5896 - val_loss: 0.7379 - val_acc: 0.6226
# Epoch 5/100
# 13761/13761 [==============================] - 5s 365us/step - loss: 0.5976 - acc: 0.6436 - val_loss: 0.7634 - val_acc: 0.5697
# Epoch 6/100
# 13761/13761 [==============================] - 5s 364us/step - loss: 0.5871 - acc: 0.6392 - val_loss: 0.7780 - val_acc: 0.5350
# Epoch 7/100
# 13761/13761 [==============================] - 5s 366us/step - loss: 0.5777 - acc: 0.6444 - val_loss: 0.7759 - val_acc: 0.5716
# Epoch 8/100
# 13761/13761 [==============================] - 5s 363us/step - loss: 0.5743 - acc: 0.6629 - val_loss: 0.7818 - val_acc: 0.5703
# Epoch 9/100
# 13761/13761 [==============================] - 5s 363us/step - loss: 0.5715 - acc: 0.6562 - val_loss: 0.7821 - val_acc: 0.5853
# Epoch 00009: early stopping
# [[3030 1470]
#  [ 123  209]]
# accuracy  : 0.6703228476821192
# f1 score  : 0.20785678766782698
# precision : 0.12447885646217986
# recall    : 0.6295180722891566
# WA        : 65.14257028112449
#               precision    recall  f1-score   support
#
#            0       0.96      0.67      0.79      4500
#            1       0.12      0.63      0.21       332
#
#     accuracy                           0.67      4832
#    macro avg       0.54      0.65      0.50      4832
# weighted avg       0.90      0.67      0.75      4832

# %%
from sklearn.utils import class_weight
class_weight = class_weight.compute_class_weight('balanced',np.unique(Train_labels_disgust.squeeze()),Train_labels_disgust.squeeze())
print(class_weight)

i = Input(shape=(20,409))
x = LSTM(128,return_sequences = True)(i)
x = LSTM(64,return_sequences = True)(x)
x = LSTM(32,return_sequences = False)(x)
x = Dense(32,activation='relu')(x)
x = Dense(1,activation='sigmoid')(x)

model = Model(i,x)
print(model.summary())
model.compile('adam','binary_crossentropy',metrics=['accuracy'])

es = EarlyStopping(monitor='val_acc',mode='max' ,patience=5, min_delta=0.0001,verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_acc', factor=0.2,patience=2,min_lr=0.00001)
model.fit(train_concat,Train_labels_disgust,512,epochs=100,validation_split=0.1,callbacks=[es,reduce_lr],
         class_weight=dict(enumerate(class_weight)))


y_pred = (model.predict(test_concat)>0.5).astype("float")
y_true = Test_labels_disgust
cm = confusion_matrix(y_true,y_pred)

p = precision_score(y_true,y_pred)
a = accuracy_score(y_true,y_pred)
r = recall_score(y_true,y_pred)
f = f1_score(y_true,y_pred)
print(cm)
print("accuracy  :",a)
print("f1 score  :",f)
print("precision :",p)
print("recall    :",r)


TP = cm[1][1]
TN = cm[0][0]
P = Test_labels_disgust.sum()
N = 4832-P
wa = ((TP*N/P) + TN)/(0.02*N)
print("WA        :",wa)
print(classification_report(y_true,y_pred))
model.save("EF_CW_disgust.h5")
# Out:
# [0.60819411 2.81066176]
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         (None, 20, 409)           0
# _________________________________________________________________
# lstm_16 (LSTM)               (None, 20, 128)           275456
# _________________________________________________________________
# lstm_17 (LSTM)               (None, 20, 64)            49408
# _________________________________________________________________
# lstm_18 (LSTM)               (None, 32)                12416
# _________________________________________________________________
# dense_11 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 338,369
# Trainable params: 338,369
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 13761 samples, validate on 1529 samples
# Epoch 1/100
# 13761/13761 [==============================] - 9s 665us/step - loss: 0.6251 - acc: 0.7172 - val_loss: 0.5639 - val_acc: 0.7593
# Epoch 2/100
# 13761/13761 [==============================] - 5s 356us/step - loss: 0.6057 - acc: 0.7379 - val_loss: 0.5554 - val_acc: 0.7809
# Epoch 3/100
# 13761/13761 [==============================] - 5s 360us/step - loss: 0.5920 - acc: 0.7523 - val_loss: 0.5566 - val_acc: 0.7848
# Epoch 4/100
# 13761/13761 [==============================] - 5s 361us/step - loss: 0.5832 - acc: 0.7485 - val_loss: 0.5646 - val_acc: 0.7220
# Epoch 5/100
# 13761/13761 [==============================] - 5s 360us/step - loss: 0.5714 - acc: 0.7262 - val_loss: 0.5574 - val_acc: 0.7855
# Epoch 6/100
# 13761/13761 [==============================] - 5s 362us/step - loss: 0.5692 - acc: 0.7490 - val_loss: 0.5504 - val_acc: 0.7600
# Epoch 7/100
# 13761/13761 [==============================] - 5s 362us/step - loss: 0.5417 - acc: 0.7378 - val_loss: 0.5533 - val_acc: 0.7390
# Epoch 8/100
# 13761/13761 [==============================] - 5s 360us/step - loss: 0.5111 - acc: 0.7464 - val_loss: 0.5655 - val_acc: 0.7063
# Epoch 9/100
# 13761/13761 [==============================] - 5s 362us/step - loss: 0.4967 - acc: 0.7499 - val_loss: 0.5701 - val_acc: 0.7279
# Epoch 10/100
# 13761/13761 [==============================] - 5s 360us/step - loss: 0.4826 - acc: 0.7594 - val_loss: 0.5702 - val_acc: 0.7469
# Epoch 00010: early stopping
# [[2797 1113]
#  [ 281  641]]
# accuracy  : 0.7115066225165563
# f1 score  : 0.47907324364723464
# precision : 0.3654503990877993
# recall    : 0.6952277657266811
# WA        : 70.52865171344403
#               precision    recall  f1-score   support
#
#            0       0.91      0.72      0.80      3910
#            1       0.37      0.70      0.48       922
#
#     accuracy                           0.71      4832
#    macro avg       0.64      0.71      0.64      4832
# weighted avg       0.81      0.71      0.74      4832

# %%
from sklearn.utils import class_weight
class_weight = class_weight.compute_class_weight('balanced',np.unique(Train_labels_surprise.squeeze()),Train_labels_surprise.squeeze())
print(class_weight)

i = Input(shape=(20,409))
x = LSTM(128,return_sequences = True)(i)
x = LSTM(64,return_sequences = True)(x)
x = LSTM(32,return_sequences = False)(x)
x = Dense(32,activation='relu')(x)
x = Dense(1,activation='sigmoid')(x)

model = Model(i,x)
print(model.summary())
model.compile('adam','binary_crossentropy',metrics=['accuracy'])

es = EarlyStopping(monitor='val_acc',mode='max' ,patience=5, min_delta=0.0001,verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_acc', factor=0.2,patience=2,min_lr=0.00001)
model.fit(train_concat,Train_labels_surprise,512,epochs=100,validation_split=0.1,callbacks=[es,reduce_lr],
         class_weight=dict(enumerate(class_weight)))


y_pred = (model.predict(test_concat)>0.5).astype("float")
y_true = Test_labels_surprise
cm = confusion_matrix(y_true,y_pred)

p = precision_score(y_true,y_pred)
a = accuracy_score(y_true,y_pred)
r = recall_score(y_true,y_pred)
f = f1_score(y_true,y_pred)
print(cm)
print("accuracy  :",a)
print("f1 score  :",f)
print("precision :",p)
print("recall    :",r)


TP = cm[1][1]
TN = cm[0][0]
P = Test_labels_surprise.sum()
N = 4832-P
wa = ((TP*N/P) + TN)/(0.02*N)
print("WA        :",wa)
print(classification_report(y_true,y_pred))
model.save("EF_CW_surprise.h5")
# Out:
# [0.55689103 4.8943662 ]
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         (None, 20, 409)           0
# _________________________________________________________________
# lstm_19 (LSTM)               (None, 20, 128)           275456
# _________________________________________________________________
# lstm_20 (LSTM)               (None, 20, 64)            49408
# _________________________________________________________________
# lstm_21 (LSTM)               (None, 32)                12416
# _________________________________________________________________
# dense_13 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 338,369
# Trainable params: 338,369
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 13761 samples, validate on 1529 samples
# Epoch 1/100
# 13761/13761 [==============================] - 10s 716us/step - loss: 0.6921 - acc: 0.5804 - val_loss: 0.6443 - val_acc: 0.7037
# Epoch 2/100
# 13761/13761 [==============================] - 5s 364us/step - loss: 0.6832 - acc: 0.5591 - val_loss: 0.6397 - val_acc: 0.6403
# Epoch 3/100
# 13761/13761 [==============================] - 5s 363us/step - loss: 0.6678 - acc: 0.6196 - val_loss: 0.6435 - val_acc: 0.6272
# Epoch 4/100
# 13761/13761 [==============================] - 5s 365us/step - loss: 0.6462 - acc: 0.6258 - val_loss: 0.6512 - val_acc: 0.6109
# Epoch 5/100
# 13761/13761 [==============================] - 5s 364us/step - loss: 0.6350 - acc: 0.6463 - val_loss: 0.6542 - val_acc: 0.6030
# Epoch 6/100
# 13761/13761 [==============================] - 5s 364us/step - loss: 0.6204 - acc: 0.6638 - val_loss: 0.6596 - val_acc: 0.6710
# Epoch 00006: early stopping
# [[2923 1430]
#  [ 258  221]]
# accuracy  : 0.6506622516556292
# f1 score  : 0.2075117370892019
# precision : 0.13385826771653545
# recall    : 0.4613778705636743
# WA        : 56.64343981809871
#               precision    recall  f1-score   support
#
#            0       0.92      0.67      0.78      4353
#            1       0.13      0.46      0.21       479
#
#     accuracy                           0.65      4832
#    macro avg       0.53      0.57      0.49      4832
# weighted avg       0.84      0.65      0.72      4832

# %%
files.download("EF_CW_happy.h5")
files.download("EF_CW_angry.h5")
files.download("EF_CW_sad.h5")
files.download("EF_CW_fear.h5")
files.download("EF_CW_surprise.h5")
files.download("EF_CW_disgust.h5")
