# %%
# !git clone "https://github.com/convman/Multimodal.git"
# Out:
# Cloning into 'Multimodal'...
# remote: Enumerating objects: 14, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 589 (delta 0), reused 0 (delta 0), pack-reused 575
# Receiving objects: 100% (589/589), 1009.21 MiB | 30.75 MiB/s, done.
# Resolving deltas: 100% (202/202), done.
# Checking out files: 100% (346/346), done.

# %%
cd Multimodal/
# Out:
# /content/Multimodal

# %%
# !chmod +x data/dataset_download.sh
# !./data/dataset_download.sh
# Out:
# --2019-07-27 16:05:10--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/data/audio_test.h5
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 57213024 (55M)
# Saving to: ‘audio_test.h5’
#
# audio_test.h5       100%[===================>]  54.56M  14.9MB/s    in 4.1s
#
# 2019-07-27 16:05:15 (13.4 MB/s) - ‘audio_test.h5’ saved [57213024/57213024]
#
# --2019-07-27 16:05:15--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/data/audio_train.h5
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 181035744 (173M)
# Saving to: ‘audio_train.h5’
#
# audio_train.h5      100%[===================>] 172.65M  15.0MB/s    in 12s
#
# 2019-07-27 16:05:27 (14.3 MB/s) - ‘audio_train.h5’ saved [181035744/181035744]
#
# --2019-07-27 16:05:27--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/data/text_test_emb.h5
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 231938144 (221M)
# Saving to: ‘text_test_emb.h5’
#
# text_test_emb.h5    100%[===================>] 221.19M  15.1MB/s    in 15s
#
# 2019-07-27 16:05:42 (14.9 MB/s) - ‘text_test_emb.h5’ saved [231938144/231938144]
#
# --2019-07-27 16:05:42--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/data/text_train_emb.h5
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 733922144 (700M)
# Saving to: ‘text_train_emb.h5’
#
# text_train_emb.h5   100%[===================>] 699.92M  15.5MB/s    in 46s
#
# 2019-07-27 16:06:28 (15.2 MB/s) - ‘text_train_emb.h5’ saved [733922144/733922144]
#
# --2019-07-27 16:06:28--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/data/video_test.h5
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 27061344 (26M)
# Saving to: ‘video_test.h5’
#
# video_test.h5       100%[===================>]  25.81M  11.9MB/s    in 2.2s
#
# 2019-07-27 16:06:30 (11.9 MB/s) - ‘video_test.h5’ saved [27061344/27061344]
#
# --2019-07-27 16:06:30--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/data/video_train.h5
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 85626144 (82M)
# Saving to: ‘video_train.h5’
#
# video_train.h5      100%[===================>]  81.66M  15.4MB/s    in 5.7s
#
# 2019-07-27 16:06:36 (14.3 MB/s) - ‘video_train.h5’ saved [85626144/85626144]
#
# --2019-07-27 16:06:36--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Test_labels_2class.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9664 (9.4K) [text/csv]
# Saving to: ‘mosi2uni_Test_labels_2class.csv’
#
# mosi2uni_Test_label 100%[===================>]   9.44K  --.-KB/s    in 0s
#
# 2019-07-27 16:06:36 (43.8 MB/s) - ‘mosi2uni_Test_labels_2class.csv’ saved [9664/9664]
#
# --2019-07-27 16:06:36--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Test_labels_5class.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9664 (9.4K) [text/csv]
# Saving to: ‘mosi2uni_Test_labels_5class.csv’
#
# mosi2uni_Test_label 100%[===================>]   9.44K  --.-KB/s    in 0s
#
# 2019-07-27 16:06:36 (173 MB/s) - ‘mosi2uni_Test_labels_5class.csv’ saved [9664/9664]
#
# --2019-07-27 16:06:36--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Test_labels_7class.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9664 (9.4K) [text/csv]
# Saving to: ‘mosi2uni_Test_labels_7class.csv’
#
# mosi2uni_Test_label 100%[===================>]   9.44K  --.-KB/s    in 0s
#
# 2019-07-27 16:06:37 (126 MB/s) - ‘mosi2uni_Test_labels_7class.csv’ saved [9664/9664]
#
# --2019-07-27 16:06:37--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Test_labels_angry.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9664 (9.4K) [text/csv]
# Saving to: ‘mosi2uni_Test_labels_angry.csv’
#
# mosi2uni_Test_label 100%[===================>]   9.44K  --.-KB/s    in 0s
#
# 2019-07-27 16:06:37 (45.0 MB/s) - ‘mosi2uni_Test_labels_angry.csv’ saved [9664/9664]
#
# --2019-07-27 16:06:37--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Test_labels_disgust.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9664 (9.4K) [text/csv]
# Saving to: ‘mosi2uni_Test_labels_disgust.csv’
#
# mosi2uni_Test_label 100%[===================>]   9.44K  --.-KB/s    in 0s
#
# 2019-07-27 16:06:37 (104 MB/s) - ‘mosi2uni_Test_labels_disgust.csv’ saved [9664/9664]
#
# --2019-07-27 16:06:37--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Test_labels_fear.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9664 (9.4K) [text/csv]
# Saving to: ‘mosi2uni_Test_labels_fear.csv’
#
# mosi2uni_Test_label 100%[===================>]   9.44K  --.-KB/s    in 0s
#
# 2019-07-27 16:06:37 (87.4 MB/s) - ‘mosi2uni_Test_labels_fear.csv’ saved [9664/9664]
#
# --2019-07-27 16:06:37--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Test_labels_happy.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9664 (9.4K) [text/csv]
# Saving to: ‘mosi2uni_Test_labels_happy.csv’
#
# mosi2uni_Test_label 100%[===================>]   9.44K  --.-KB/s    in 0s
#
# 2019-07-27 16:06:37 (66.6 MB/s) - ‘mosi2uni_Test_labels_happy.csv’ saved [9664/9664]
#
# --2019-07-27 16:06:37--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Test_labels_sad.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9664 (9.4K) [text/csv]
# Saving to: ‘mosi2uni_Test_labels_sad.csv’
#
# mosi2uni_Test_label 100%[===================>]   9.44K  --.-KB/s    in 0s
#
# 2019-07-27 16:06:37 (28.2 MB/s) - ‘mosi2uni_Test_labels_sad.csv’ saved [9664/9664]
#
# --2019-07-27 16:06:37--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Test_labels_surprise.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9664 (9.4K) [text/csv]
# Saving to: ‘mosi2uni_Test_labels_surprise.csv’
#
# mosi2uni_Test_label 100%[===================>]   9.44K  --.-KB/s    in 0s
#
# 2019-07-27 16:06:38 (27.7 MB/s) - ‘mosi2uni_Test_labels_surprise.csv’ saved [9664/9664]
#
# --2019-07-27 16:06:38--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Train_labels_2class.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 30580 (30K) [text/csv]
# Saving to: ‘mosi2uni_Train_labels_2class.csv’
#
# mosi2uni_Train_labe 100%[===================>]  29.86K  --.-KB/s    in 0.07s
#
# 2019-07-27 16:06:38 (405 KB/s) - ‘mosi2uni_Train_labels_2class.csv’ saved [30580/30580]
#
# --2019-07-27 16:06:38--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Train_labels_5class.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 30580 (30K) [text/csv]
# Saving to: ‘mosi2uni_Train_labels_5class.csv’
#
# mosi2uni_Train_labe 100%[===================>]  29.86K  --.-KB/s    in 0.07s
#
# 2019-07-27 16:06:38 (422 KB/s) - ‘mosi2uni_Train_labels_5class.csv’ saved [30580/30580]
#
# --2019-07-27 16:06:38--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Train_labels_7class.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 30580 (30K) [text/csv]
# Saving to: ‘mosi2uni_Train_labels_7class.csv’
#
# mosi2uni_Train_labe 100%[===================>]  29.86K  --.-KB/s    in 0.07s
#
# 2019-07-27 16:06:38 (405 KB/s) - ‘mosi2uni_Train_labels_7class.csv’ saved [30580/30580]
#
# --2019-07-27 16:06:38--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Train_labels_angry.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 30580 (30K) [text/csv]
# Saving to: ‘mosi2uni_Train_labels_angry.csv’
#
# mosi2uni_Train_labe 100%[===================>]  29.86K  --.-KB/s    in 0.07s
#
# 2019-07-27 16:06:38 (406 KB/s) - ‘mosi2uni_Train_labels_angry.csv’ saved [30580/30580]
#
# --2019-07-27 16:06:38--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Train_labels_disgust.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 30580 (30K) [text/csv]
# Saving to: ‘mosi2uni_Train_labels_disgust.csv’
#
# mosi2uni_Train_labe 100%[===================>]  29.86K  --.-KB/s    in 0.07s
#
# 2019-07-27 16:06:39 (406 KB/s) - ‘mosi2uni_Train_labels_disgust.csv’ saved [30580/30580]
#
# --2019-07-27 16:06:39--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Train_labels_fear.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 30580 (30K) [text/csv]
# Saving to: ‘mosi2uni_Train_labels_fear.csv’
#
# mosi2uni_Train_labe 100%[===================>]  29.86K  --.-KB/s    in 0.07s
#
# 2019-07-27 16:06:39 (405 KB/s) - ‘mosi2uni_Train_labels_fear.csv’ saved [30580/30580]
#
# --2019-07-27 16:06:39--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Train_labels_happy.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 30580 (30K) [text/csv]
# Saving to: ‘mosi2uni_Train_labels_happy.csv’
#
# mosi2uni_Train_labe 100%[===================>]  29.86K  --.-KB/s    in 0.07s
#
# 2019-07-27 16:06:39 (407 KB/s) - ‘mosi2uni_Train_labels_happy.csv’ saved [30580/30580]
#
# --2019-07-27 16:06:39--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Train_labels_sad.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 30580 (30K) [text/csv]
# Saving to: ‘mosi2uni_Train_labels_sad.csv’
#
# mosi2uni_Train_labe 100%[===================>]  29.86K  --.-KB/s    in 0.07s
#
# 2019-07-27 16:06:39 (424 KB/s) - ‘mosi2uni_Train_labels_sad.csv’ saved [30580/30580]
#
# --2019-07-27 16:06:39--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Train_labels_surprise.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 30580 (30K) [text/csv]
# Saving to: ‘mosi2uni_Train_labels_surprise.csv’
#
# mosi2uni_Train_labe 100%[===================>]  29.86K  --.-KB/s    in 0.07s
#
# 2019-07-27 16:06:40 (404 KB/s) - ‘mosi2uni_Train_labels_surprise.csv’ saved [30580/30580]

# %%
import pandas as pd
import numpy as np
import h5py
from sklearn.metrics import classification_report
from keras.models import load_model
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import *
from sklearn.utils.multiclass import unique_labels
import keras
import tensorflow as tf
from time import time
import scipy
from keras import layers
from google.colab import files	
from sklearn.utils import class_weight
from keras.models import load_model
from keras.models import Model,Sequential,Model
from keras.layers import *
from keras.callbacks import TensorBoard
from keras import callbacks
from keras.callbacks import *
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
import pandas as pd
import numpy as np
import h5py

Test_labels_fear = np.array(pd.read_csv("mosi2uni_Test_labels_fear.csv",header=None))
Train_labels_fear = np.array(pd.read_csv("mosi2uni_Train_labels_fear.csv",header=None))

Test_labels_happy = np.array(pd.read_csv("mosi2uni_Test_labels_happy.csv",header=None))
Train_labels_happy = np.array(pd.read_csv("mosi2uni_Train_labels_happy.csv",header=None))

Test_labels_sad = np.array(pd.read_csv("mosi2uni_Test_labels_sad.csv",header=None))
Train_labels_sad = np.array(pd.read_csv("mosi2uni_Train_labels_sad.csv",header=None))

Test_labels_disgust = np.array(pd.read_csv("mosi2uni_Test_labels_disgust.csv",header=None))
Train_labels_disgust = np.array(pd.read_csv("mosi2uni_Train_labels_disgust.csv",header=None))

Test_labels_surprise = np.array(pd.read_csv("mosi2uni_Test_labels_surprise.csv",header=None))
Train_labels_surprise = np.array(pd.read_csv("mosi2uni_Train_labels_surprise.csv",header=None))

Test_labels_angry = np.array(pd.read_csv("mosi2uni_Test_labels_angry.csv",header=None))
Train_labels_angry = np.array(pd.read_csv("mosi2uni_Train_labels_angry.csv",header=None))

train_video = h5py.File("video_train.h5","r")
train_video = np.array(train_video.get('d1'))
test_video = h5py.File("video_test.h5","r")
test_video = np.array(test_video.get('d1'))

train_audio = h5py.File("audio_train.h5","r")
train_audio = np.array(train_audio.get('d1'))
test_audio = h5py.File("audio_test.h5","r")
test_audio = np.array(test_audio.get('d1'))

train_text = h5py.File("text_train_emb.h5","r")
train_text = np.array(train_text.get('d1'))
test_text = h5py.File("text_test_emb.h5","r")
test_text = np.array(test_text.get('d1'))

# %%
from sklearn.utils import class_weight
class_weight = class_weight.compute_class_weight('balanced',np.unique(Train_labels_happy.squeeze()),Train_labels_happy.squeeze())

i_v = Input(shape=(20,35))
i_a = Input(shape=(20,74))
i_t = Input(shape=(20,300))

v = LSTM(64,return_sequences = True)(i_v)
v = LSTM(32,return_sequences = True)(v)
v = LSTM(32,return_sequences = False)(v)
v = Dense(32,activation='relu')(v)

a = LSTM(64,return_sequences = True)(i_a)
a = LSTM(32,return_sequences = True)(a)
a = LSTM(32,return_sequences = False)(a)
a = Dense(32,activation='relu')(a)

t = LSTM(128,return_sequences = True)(i_t)
t = LSTM(64,return_sequences = True)(t)
t = LSTM(32,return_sequences = False)(t)
t = Dense(32,activation='relu')(t)

merge = concatenate([v,a,t])
y = Dense(32,activation='relu')(merge)
y = Dense(1,activation='sigmoid')(y)

model = Model([i_v,i_a,i_t],y)
print(model.summary())
model.compile('adam','binary_crossentropy',metrics=['accuracy'])

es = EarlyStopping(monitor='val_acc',mode='max' ,patience=5, min_delta=0.0001,verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_acc', factor=0.2,patience=2,min_lr=0.00001)
model.fit([train_video,train_audio,train_text],Train_labels_happy,512,epochs=100,validation_split=0.1,callbacks=[es,reduce_lr],
         class_weight=dict(enumerate(class_weight)))


y_pred = (model.predict([test_video,test_audio,test_text])>0.5).astype("float")
y_true = Test_labels_happy
cm = confusion_matrix(y_true,y_pred)

p = precision_score(y_true,y_pred)
a = accuracy_score(y_true,y_pred)
r = recall_score(y_true,y_pred)
f = f1_score(y_true,y_pred)
print(class_weight)
print(cm)
print("accuracy  :",a)
print("f1 score  :",f)
print("precision :",p)
print("recall    :",r)


TP = cm[1][1]
TN = cm[0][0]
P = Test_labels_happy.sum()
N = 4832-P
wa = ((TP*N/P) + TN)/(0.02*N)
print("WA        :",wa)
print(classification_report(y_true,y_pred))
model.save("LF_CW_happy.h5")
# Out:
# W0727 16:19:36.609092 139982898333568 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0727 16:19:36.639807 139982898333568 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3376: The name tf.log is deprecated. Please use tf.math.log instead.
#
# W0727 16:19:36.648356 139982898333568 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_7 (InputLayer)            (None, 20, 35)       0
# __________________________________________________________________________________________________
# input_8 (InputLayer)            (None, 20, 74)       0
# __________________________________________________________________________________________________
# input_9 (InputLayer)            (None, 20, 300)      0
# __________________________________________________________________________________________________
# lstm_19 (LSTM)                  (None, 20, 64)       25600       input_7[0][0]
# __________________________________________________________________________________________________
# lstm_22 (LSTM)                  (None, 20, 64)       35584       input_8[0][0]
# __________________________________________________________________________________________________
# lstm_25 (LSTM)                  (None, 20, 128)      219648      input_9[0][0]
# __________________________________________________________________________________________________
# lstm_20 (LSTM)                  (None, 20, 32)       12416       lstm_19[0][0]
# __________________________________________________________________________________________________
# lstm_23 (LSTM)                  (None, 20, 32)       12416       lstm_22[0][0]
# __________________________________________________________________________________________________
# lstm_26 (LSTM)                  (None, 20, 64)       49408       lstm_25[0][0]
# __________________________________________________________________________________________________
# lstm_21 (LSTM)                  (None, 32)           8320        lstm_20[0][0]
# __________________________________________________________________________________________________
# lstm_24 (LSTM)                  (None, 32)           8320        lstm_23[0][0]
# __________________________________________________________________________________________________
# lstm_27 (LSTM)                  (None, 32)           12416       lstm_26[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 32)           1056        lstm_21[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 32)           1056        lstm_24[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 32)           1056        lstm_27[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 96)           0           dense_11[0][0]
#                                                                  dense_12[0][0]
#                                                                  dense_13[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 32)           3104        concatenate_3[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 1)            33          dense_14[0][0]
# ==================================================================================================
# Total params: 390,433
# Trainable params: 390,433
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# W0727 16:19:43.602465 139982898333568 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
# Train on 13761 samples, validate on 1529 samples
# Epoch 1/100
# 13761/13761 [==============================] - 22s 2ms/step - loss: 0.6565 - acc: 0.6124 - val_loss: 0.6479 - val_acc: 0.6187
# Epoch 2/100
# 13761/13761 [==============================] - 12s 841us/step - loss: 0.6068 - acc: 0.6703 - val_loss: 0.6315 - val_acc: 0.6266
# Epoch 3/100
# 13761/13761 [==============================] - 12s 843us/step - loss: 0.5825 - acc: 0.6890 - val_loss: 0.6308 - val_acc: 0.6305
# Epoch 4/100
# 13761/13761 [==============================] - 12s 846us/step - loss: 0.5715 - acc: 0.6941 - val_loss: 0.6387 - val_acc: 0.6377
# Epoch 5/100
# 13761/13761 [==============================] - 12s 838us/step - loss: 0.5499 - acc: 0.7116 - val_loss: 0.6360 - val_acc: 0.6364
# Epoch 6/100
# 13761/13761 [==============================] - 12s 837us/step - loss: 0.5325 - acc: 0.7254 - val_loss: 0.6489 - val_acc: 0.6422
# Epoch 7/100
# 13761/13761 [==============================] - 12s 841us/step - loss: 0.5157 - acc: 0.7380 - val_loss: 0.6597 - val_acc: 0.6344
# Epoch 8/100
# 13761/13761 [==============================] - 12s 839us/step - loss: 0.5001 - acc: 0.7446 - val_loss: 0.6732 - val_acc: 0.6416
# Epoch 9/100
# 13761/13761 [==============================] - 12s 836us/step - loss: 0.4618 - acc: 0.7718 - val_loss: 0.6888 - val_acc: 0.6351
# Epoch 10/100
# 13761/13761 [==============================] - 12s 838us/step - loss: 0.4442 - acc: 0.7831 - val_loss: 0.7174 - val_acc: 0.6364
# Epoch 11/100
# 13761/13761 [==============================] - 12s 840us/step - loss: 0.4311 - acc: 0.7912 - val_loss: 0.7173 - val_acc: 0.6383
# Epoch 00011: early stopping
# [1.07027859 0.93838223]
# [[1682  628]
#  [1005 1517]]
# accuracy  : 0.6620447019867549
# f1 score  : 0.6500964216841655
# precision : 0.7072261072261072
# recall    : 0.6015067406819984
# WA        : 66.48226344102632
#               precision    recall  f1-score   support
#
#            0       0.63      0.73      0.67      2310
#            1       0.71      0.60      0.65      2522
#
#     accuracy                           0.66      4832
#    macro avg       0.67      0.66      0.66      4832
# weighted avg       0.67      0.66      0.66      4832

# %%
from sklearn.utils import class_weight
class_weight = class_weight.compute_class_weight('balanced',np.unique(Train_labels_angry.squeeze()),Train_labels_angry.squeeze())

i_v = Input(shape=(20,35))
i_a = Input(shape=(20,74))
i_t = Input(shape=(20,300))

v = LSTM(64,return_sequences = True)(i_v)
v = LSTM(32,return_sequences = True)(v)
v = LSTM(32,return_sequences = False)(v)
v = Dense(32,activation='relu')(v)

a = LSTM(64,return_sequences = True)(i_a)
a = LSTM(32,return_sequences = True)(a)
a = LSTM(32,return_sequences = False)(a)
a = Dense(32,activation='relu')(a)

t = LSTM(128,return_sequences = True)(i_t)
t = LSTM(64,return_sequences = True)(t)
t = LSTM(32,return_sequences = False)(t)
t = Dense(32,activation='relu')(t)

merge = concatenate([v,a,t])
y = Dense(32,activation='relu')(merge)
y = Dense(1,activation='sigmoid')(y)

model = Model([i_v,i_a,i_t],y)
print(model.summary())
model.compile('adam','binary_crossentropy',metrics=['accuracy'])

es = EarlyStopping(monitor='val_acc',mode='max' ,patience=5, min_delta=0.0001,verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_acc', factor=0.2,patience=2,min_lr=0.00001)
model.fit([train_video,train_audio,train_text],Train_labels_angry,512,epochs=100,validation_split=0.1,callbacks=[es,reduce_lr],
         class_weight=dict(enumerate(class_weight)))


y_pred = (model.predict([test_video,test_audio,test_text])>0.5).astype("float")
y_true = Test_labels_angry
cm = confusion_matrix(y_true,y_pred)

p = precision_score(y_true,y_pred)
a = accuracy_score(y_true,y_pred)
r = recall_score(y_true,y_pred)
f = f1_score(y_true,y_pred)
print(class_weight)
print(cm)
print("accuracy  :",a)
print("f1 score  :",f)
print("precision :",p)
print("recall    :",r)


TP = cm[1][1]
TN = cm[0][0]
P = Test_labels_angry.sum()
N = 4832-P
wa = ((TP*N/P) + TN)/(0.02*N)
print("WA        :",wa)
print(classification_report(y_true,y_pred))
model.save("LF_CW_angry.h5")
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_10 (InputLayer)           (None, 20, 35)       0
# __________________________________________________________________________________________________
# input_11 (InputLayer)           (None, 20, 74)       0
# __________________________________________________________________________________________________
# input_12 (InputLayer)           (None, 20, 300)      0
# __________________________________________________________________________________________________
# lstm_28 (LSTM)                  (None, 20, 64)       25600       input_10[0][0]
# __________________________________________________________________________________________________
# lstm_31 (LSTM)                  (None, 20, 64)       35584       input_11[0][0]
# __________________________________________________________________________________________________
# lstm_34 (LSTM)                  (None, 20, 128)      219648      input_12[0][0]
# __________________________________________________________________________________________________
# lstm_29 (LSTM)                  (None, 20, 32)       12416       lstm_28[0][0]
# __________________________________________________________________________________________________
# lstm_32 (LSTM)                  (None, 20, 32)       12416       lstm_31[0][0]
# __________________________________________________________________________________________________
# lstm_35 (LSTM)                  (None, 20, 64)       49408       lstm_34[0][0]
# __________________________________________________________________________________________________
# lstm_30 (LSTM)                  (None, 32)           8320        lstm_29[0][0]
# __________________________________________________________________________________________________
# lstm_33 (LSTM)                  (None, 32)           8320        lstm_32[0][0]
# __________________________________________________________________________________________________
# lstm_36 (LSTM)                  (None, 32)           12416       lstm_35[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 32)           1056        lstm_30[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 32)           1056        lstm_33[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 32)           1056        lstm_36[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 96)           0           dense_16[0][0]
#                                                                  dense_17[0][0]
#                                                                  dense_18[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 32)           3104        concatenate_4[0][0]
# __________________________________________________________________________________________________
# dense_20 (Dense)                (None, 1)            33          dense_19[0][0]
# ==================================================================================================
# Total params: 390,433
# Trainable params: 390,433
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Train on 13761 samples, validate on 1529 samples
# Epoch 1/100
# 13761/13761 [==============================] - 20s 1ms/step - loss: 0.6697 - acc: 0.6406 - val_loss: 0.6326 - val_acc: 0.6050
# Epoch 2/100
# 13761/13761 [==============================] - 12s 842us/step - loss: 0.6310 - acc: 0.6313 - val_loss: 0.6135 - val_acc: 0.6266
# Epoch 3/100
# 13761/13761 [==============================] - 12s 846us/step - loss: 0.6086 - acc: 0.6420 - val_loss: 0.6271 - val_acc: 0.5507
# Epoch 4/100
# 13761/13761 [==============================] - 12s 860us/step - loss: 0.5869 - acc: 0.6535 - val_loss: 0.6121 - val_acc: 0.6396
# Epoch 5/100
# 13761/13761 [==============================] - 12s 848us/step - loss: 0.5616 - acc: 0.6728 - val_loss: 0.6130 - val_acc: 0.6645
# Epoch 6/100
# 13761/13761 [==============================] - 12s 844us/step - loss: 0.5400 - acc: 0.6838 - val_loss: 0.6344 - val_acc: 0.6226
# Epoch 7/100
# 13761/13761 [==============================] - 12s 841us/step - loss: 0.5154 - acc: 0.6997 - val_loss: 0.6743 - val_acc: 0.6226
# Epoch 8/100
# 13761/13761 [==============================] - 12s 847us/step - loss: 0.4767 - acc: 0.7265 - val_loss: 0.6836 - val_acc: 0.6305
# Epoch 9/100
# 13761/13761 [==============================] - 12s 852us/step - loss: 0.4525 - acc: 0.7457 - val_loss: 0.7169 - val_acc: 0.6422
# Epoch 10/100
# 13761/13761 [==============================] - 12s 850us/step - loss: 0.4361 - acc: 0.7575 - val_loss: 0.7251 - val_acc: 0.6409
# Epoch 00010: early stopping
# [0.64531105 2.22044728]
# [[2379 1482]
#  [ 332  639]]
# accuracy  : 0.6245860927152318
# f1 score  : 0.4133247089262614
# precision : 0.3012729844413013
# recall    : 0.6580844490216272
# WA        : 63.71230325916217
#               precision    recall  f1-score   support
#
#            0       0.88      0.62      0.72      3861
#            1       0.30      0.66      0.41       971
#
#     accuracy                           0.62      4832
#    macro avg       0.59      0.64      0.57      4832
# weighted avg       0.76      0.62      0.66      4832

# %%
from sklearn.utils import class_weight
class_weight = class_weight.compute_class_weight('balanced',np.unique(Train_labels_sad.squeeze()),Train_labels_sad.squeeze())

i_v = Input(shape=(20,35))
i_a = Input(shape=(20,74))
i_t = Input(shape=(20,300))

v = LSTM(64,return_sequences = True)(i_v)
v = LSTM(32,return_sequences = True)(v)
v = LSTM(32,return_sequences = False)(v)
v = Dense(32,activation='relu')(v)

a = LSTM(64,return_sequences = True)(i_a)
a = LSTM(32,return_sequences = True)(a)
a = LSTM(32,return_sequences = False)(a)
a = Dense(32,activation='relu')(a)

t = LSTM(128,return_sequences = True)(i_t)
t = LSTM(64,return_sequences = True)(t)
t = LSTM(32,return_sequences = False)(t)
t = Dense(32,activation='relu')(t)

merge = concatenate([v,a,t])
y = Dense(32,activation='relu')(merge)
y = Dense(1,activation='sigmoid')(y)

model = Model([i_v,i_a,i_t],y)
print(model.summary())
model.compile('adam','binary_crossentropy',metrics=['accuracy'])

es = EarlyStopping(monitor='val_acc',mode='max' ,patience=5, min_delta=0.0001,verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_acc', factor=0.2,patience=2,min_lr=0.00001)
model.fit([train_video,train_audio,train_text],Train_labels_sad,512,epochs=100,validation_split=0.1,callbacks=[es,reduce_lr],
         class_weight=dict(enumerate(class_weight)))


y_pred = (model.predict([test_video,test_audio,test_text])>0.5).astype("float")
y_true = Test_labels_sad
cm = confusion_matrix(y_true,y_pred)

p = precision_score(y_true,y_pred)
a = accuracy_score(y_true,y_pred)
r = recall_score(y_true,y_pred)
f = f1_score(y_true,y_pred)
print(class_weight)
print(cm)
print("accuracy  :",a)
print("f1 score  :",f)
print("precision :",p)
print("recall    :",r)


TP = cm[1][1]
TN = cm[0][0]
P = Test_labels_sad.sum()
N = 4832-P
wa = ((TP*N/P) + TN)/(0.02*N)
print("WA        :",wa)
print(classification_report(y_true,y_pred))
model.save("LF_CW_sad.h5")
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_13 (InputLayer)           (None, 20, 35)       0
# __________________________________________________________________________________________________
# input_14 (InputLayer)           (None, 20, 74)       0
# __________________________________________________________________________________________________
# input_15 (InputLayer)           (None, 20, 300)      0
# __________________________________________________________________________________________________
# lstm_37 (LSTM)                  (None, 20, 64)       25600       input_13[0][0]
# __________________________________________________________________________________________________
# lstm_40 (LSTM)                  (None, 20, 64)       35584       input_14[0][0]
# __________________________________________________________________________________________________
# lstm_43 (LSTM)                  (None, 20, 128)      219648      input_15[0][0]
# __________________________________________________________________________________________________
# lstm_38 (LSTM)                  (None, 20, 32)       12416       lstm_37[0][0]
# __________________________________________________________________________________________________
# lstm_41 (LSTM)                  (None, 20, 32)       12416       lstm_40[0][0]
# __________________________________________________________________________________________________
# lstm_44 (LSTM)                  (None, 20, 64)       49408       lstm_43[0][0]
# __________________________________________________________________________________________________
# lstm_39 (LSTM)                  (None, 32)           8320        lstm_38[0][0]
# __________________________________________________________________________________________________
# lstm_42 (LSTM)                  (None, 32)           8320        lstm_41[0][0]
# __________________________________________________________________________________________________
# lstm_45 (LSTM)                  (None, 32)           12416       lstm_44[0][0]
# __________________________________________________________________________________________________
# dense_21 (Dense)                (None, 32)           1056        lstm_39[0][0]
# __________________________________________________________________________________________________
# dense_22 (Dense)                (None, 32)           1056        lstm_42[0][0]
# __________________________________________________________________________________________________
# dense_23 (Dense)                (None, 32)           1056        lstm_45[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 96)           0           dense_21[0][0]
#                                                                  dense_22[0][0]
#                                                                  dense_23[0][0]
# __________________________________________________________________________________________________
# dense_24 (Dense)                (None, 32)           3104        concatenate_5[0][0]
# __________________________________________________________________________________________________
# dense_25 (Dense)                (None, 1)            33          dense_24[0][0]
# ==================================================================================================
# Total params: 390,433
# Trainable params: 390,433
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Train on 13761 samples, validate on 1529 samples
# Epoch 1/100
# 13761/13761 [==============================] - 22s 2ms/step - loss: 0.6801 - acc: 0.6108 - val_loss: 0.6410 - val_acc: 0.6337
# Epoch 2/100
# 13761/13761 [==============================] - 12s 862us/step - loss: 0.6554 - acc: 0.5795 - val_loss: 0.6355 - val_acc: 0.5795
# Epoch 3/100
# 13761/13761 [==============================] - 12s 859us/step - loss: 0.6389 - acc: 0.5869 - val_loss: 0.6364 - val_acc: 0.5664
# Epoch 4/100
# 13761/13761 [==============================] - 12s 853us/step - loss: 0.6189 - acc: 0.6093 - val_loss: 0.6358 - val_acc: 0.5795
# Epoch 5/100
# 13761/13761 [==============================] - 12s 852us/step - loss: 0.6110 - acc: 0.6176 - val_loss: 0.6366 - val_acc: 0.6167
# Epoch 6/100
# 13761/13761 [==============================] - 12s 853us/step - loss: 0.6037 - acc: 0.6302 - val_loss: 0.6369 - val_acc: 0.5991
# Epoch 00006: early stopping
# [0.67155657 1.95724526]
# [[1843 1655]
#  [ 393  941]]
# accuracy  : 0.5761589403973509
# f1 score  : 0.47888040712468194
# precision : 0.36248073959938365
# recall    : 0.7053973013493253
# WA        : 61.61348999599686
#               precision    recall  f1-score   support
#
#            0       0.82      0.53      0.64      3498
#            1       0.36      0.71      0.48      1334
#
#     accuracy                           0.58      4832
#    macro avg       0.59      0.62      0.56      4832
# weighted avg       0.70      0.58      0.60      4832

# %%
from sklearn.utils import class_weight
class_weight = class_weight.compute_class_weight('balanced',np.unique(Train_labels_fear.squeeze()),Train_labels_fear.squeeze())

i_v = Input(shape=(20,35))
i_a = Input(shape=(20,74))
i_t = Input(shape=(20,300))

v = LSTM(64,return_sequences = True)(i_v)
v = LSTM(32,return_sequences = True)(v)
v = LSTM(32,return_sequences = False)(v)
v = Dense(32,activation='relu')(v)

a = LSTM(64,return_sequences = True)(i_a)
a = LSTM(32,return_sequences = True)(a)
a = LSTM(32,return_sequences = False)(a)
a = Dense(32,activation='relu')(a)

t = LSTM(128,return_sequences = True)(i_t)
t = LSTM(64,return_sequences = True)(t)
t = LSTM(32,return_sequences = False)(t)
t = Dense(32,activation='relu')(t)

merge = concatenate([v,a,t])
y = Dense(32,activation='relu')(merge)
y = Dense(1,activation='sigmoid')(y)

model = Model([i_v,i_a,i_t],y)
print(model.summary())
model.compile('adam','binary_crossentropy',metrics=['accuracy'])

es = EarlyStopping(monitor='val_acc',mode='max' ,patience=5, min_delta=0.0001,verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_acc', factor=0.2,patience=2,min_lr=0.00001)
model.fit([train_video,train_audio,train_text],Train_labels_fear,512,epochs=100,validation_split=0.1,callbacks=[es,reduce_lr],
         class_weight=dict(enumerate(class_weight)))


y_pred = (model.predict([test_video,test_audio,test_text])>0.5).astype("float")
y_true = Test_labels_fear
cm = confusion_matrix(y_true,y_pred)

p = precision_score(y_true,y_pred)
a = accuracy_score(y_true,y_pred)
r = recall_score(y_true,y_pred)
f = f1_score(y_true,y_pred)
print(class_weight)
print(cm)
print("accuracy  :",a)
print("f1 score  :",f)
print("precision :",p)
print("recall    :",r)


TP = cm[1][1]
TN = cm[0][0]
P = Test_labels_fear.sum()
N = 4832-P
wa = ((TP*N/P) + TN)/(0.02*N)
print("WA        :",wa)
print(classification_report(y_true,y_pred))
model.save("LF_CW_fear.h5")
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_25 (InputLayer)           (None, 20, 35)       0
# __________________________________________________________________________________________________
# input_26 (InputLayer)           (None, 20, 74)       0
# __________________________________________________________________________________________________
# input_27 (InputLayer)           (None, 20, 300)      0
# __________________________________________________________________________________________________
# lstm_73 (LSTM)                  (None, 20, 64)       25600       input_25[0][0]
# __________________________________________________________________________________________________
# lstm_76 (LSTM)                  (None, 20, 64)       35584       input_26[0][0]
# __________________________________________________________________________________________________
# lstm_79 (LSTM)                  (None, 20, 128)      219648      input_27[0][0]
# __________________________________________________________________________________________________
# lstm_74 (LSTM)                  (None, 20, 32)       12416       lstm_73[0][0]
# __________________________________________________________________________________________________
# lstm_77 (LSTM)                  (None, 20, 32)       12416       lstm_76[0][0]
# __________________________________________________________________________________________________
# lstm_80 (LSTM)                  (None, 20, 64)       49408       lstm_79[0][0]
# __________________________________________________________________________________________________
# lstm_75 (LSTM)                  (None, 32)           8320        lstm_74[0][0]
# __________________________________________________________________________________________________
# lstm_78 (LSTM)                  (None, 32)           8320        lstm_77[0][0]
# __________________________________________________________________________________________________
# lstm_81 (LSTM)                  (None, 32)           12416       lstm_80[0][0]
# __________________________________________________________________________________________________
# dense_41 (Dense)                (None, 32)           1056        lstm_75[0][0]
# __________________________________________________________________________________________________
# dense_42 (Dense)                (None, 32)           1056        lstm_78[0][0]
# __________________________________________________________________________________________________
# dense_43 (Dense)                (None, 32)           1056        lstm_81[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 96)           0           dense_41[0][0]
#                                                                  dense_42[0][0]
#                                                                  dense_43[0][0]
# __________________________________________________________________________________________________
# dense_44 (Dense)                (None, 32)           3104        concatenate_9[0][0]
# __________________________________________________________________________________________________
# dense_45 (Dense)                (None, 1)            33          dense_44[0][0]
# ==================================================================================================
# Total params: 390,433
# Trainable params: 390,433
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Train on 13761 samples, validate on 1529 samples
# Epoch 1/100
# 13761/13761 [==============================] - 28s 2ms/step - loss: 0.6715 - acc: 0.4069 - val_loss: 0.6925 - val_acc: 0.5219
# Epoch 2/100
# 13761/13761 [==============================] - 12s 878us/step - loss: 0.6330 - acc: 0.5923 - val_loss: 0.7088 - val_acc: 0.5311
# Epoch 3/100
# 13761/13761 [==============================] - 12s 863us/step - loss: 0.6090 - acc: 0.6513 - val_loss: 0.6840 - val_acc: 0.6553
# Epoch 4/100
# 13761/13761 [==============================] - 12s 868us/step - loss: 0.5782 - acc: 0.7146 - val_loss: 0.7182 - val_acc: 0.7266
# Epoch 5/100
# 13761/13761 [==============================] - 12s 860us/step - loss: 0.5564 - acc: 0.7355 - val_loss: 0.7537 - val_acc: 0.6154
# Epoch 6/100
# 13761/13761 [==============================] - 12s 867us/step - loss: 0.5074 - acc: 0.7590 - val_loss: 0.7944 - val_acc: 0.6913
# Epoch 7/100
# 13761/13761 [==============================] - 12s 870us/step - loss: 0.4465 - acc: 0.7975 - val_loss: 0.8439 - val_acc: 0.7325
# Epoch 8/100
# 13761/13761 [==============================] - 12s 862us/step - loss: 0.4182 - acc: 0.8150 - val_loss: 0.9177 - val_acc: 0.7325
# Epoch 9/100
# 13761/13761 [==============================] - 12s 866us/step - loss: 0.3966 - acc: 0.8284 - val_loss: 0.9650 - val_acc: 0.7404
# Epoch 10/100
# 13761/13761 [==============================] - 12s 868us/step - loss: 0.3758 - acc: 0.8329 - val_loss: 1.0094 - val_acc: 0.7364
# Epoch 11/100
# 13761/13761 [==============================] - 12s 883us/step - loss: 0.3588 - acc: 0.8452 - val_loss: 1.1015 - val_acc: 0.7639
# Epoch 12/100
# 13761/13761 [==============================] - 12s 866us/step - loss: 0.3419 - acc: 0.8540 - val_loss: 1.1667 - val_acc: 0.7770
# Epoch 13/100
# 13761/13761 [==============================] - 12s 872us/step - loss: 0.3192 - acc: 0.8662 - val_loss: 1.1603 - val_acc: 0.7489
# Epoch 14/100
# 13761/13761 [==============================] - 12s 867us/step - loss: 0.3047 - acc: 0.8698 - val_loss: 1.2193 - val_acc: 0.7600
# Epoch 15/100
# 13761/13761 [==============================] - 12s 861us/step - loss: 0.2831 - acc: 0.8840 - val_loss: 1.2977 - val_acc: 0.7744
# Epoch 16/100
# 13761/13761 [==============================] - 12s 863us/step - loss: 0.2756 - acc: 0.8865 - val_loss: 1.3436 - val_acc: 0.7835
# Epoch 17/100
# 13761/13761 [==============================] - 12s 863us/step - loss: 0.2719 - acc: 0.8891 - val_loss: 1.3851 - val_acc: 0.7901
# Epoch 18/100
# 13761/13761 [==============================] - 12s 862us/step - loss: 0.2669 - acc: 0.8924 - val_loss: 1.3498 - val_acc: 0.7763
# Epoch 19/100
# 13761/13761 [==============================] - 12s 866us/step - loss: 0.2638 - acc: 0.8927 - val_loss: 1.4329 - val_acc: 0.7927
# Epoch 20/100
# 13761/13761 [==============================] - 12s 862us/step - loss: 0.2595 - acc: 0.8962 - val_loss: 1.4364 - val_acc: 0.7888
# Epoch 21/100
# 13761/13761 [==============================] - 12s 865us/step - loss: 0.2561 - acc: 0.8967 - val_loss: 1.4604 - val_acc: 0.7881
# Epoch 22/100
# 13761/13761 [==============================] - 12s 858us/step - loss: 0.2512 - acc: 0.8999 - val_loss: 1.4464 - val_acc: 0.7881
# Epoch 23/100
# 13761/13761 [==============================] - 12s 859us/step - loss: 0.2503 - acc: 0.9004 - val_loss: 1.4487 - val_acc: 0.7881
# Epoch 24/100
# 13761/13761 [==============================] - 12s 861us/step - loss: 0.2492 - acc: 0.9007 - val_loss: 1.4657 - val_acc: 0.7881
# Epoch 00024: early stopping
# [0.54720492 5.79605762]
# [[3863  637]
#  [ 229  103]]
# accuracy  : 0.8207781456953642
# f1 score  : 0.1921641791044776
# precision : 0.13918918918918918
# recall    : 0.3102409638554217
# WA        : 58.4342704149933
#               precision    recall  f1-score   support
#
#            0       0.94      0.86      0.90      4500
#            1       0.14      0.31      0.19       332
#
#     accuracy                           0.82      4832
#    macro avg       0.54      0.58      0.55      4832
# weighted avg       0.89      0.82      0.85      4832

# %%
from sklearn.utils import class_weight
class_weight = class_weight.compute_class_weight('balanced',np.unique(Train_labels_surprise.squeeze()),Train_labels_surprise.squeeze())

i_v = Input(shape=(20,35))
i_a = Input(shape=(20,74))
i_t = Input(shape=(20,300))

v = LSTM(64,return_sequences = True)(i_v)
v = LSTM(32,return_sequences = True)(v)
v = LSTM(32,return_sequences = False)(v)
v = Dense(32,activation='relu')(v)

a = LSTM(64,return_sequences = True)(i_a)
a = LSTM(32,return_sequences = True)(a)
a = LSTM(32,return_sequences = False)(a)
a = Dense(32,activation='relu')(a)

t = LSTM(128,return_sequences = True)(i_t)
t = LSTM(64,return_sequences = True)(t)
t = LSTM(32,return_sequences = False)(t)
t = Dense(32,activation='relu')(t)

merge = concatenate([v,a,t])
y = Dense(32,activation='relu')(merge)
y = Dense(1,activation='sigmoid')(y)

model = Model([i_v,i_a,i_t],y)
print(model.summary())
model.compile('adam','binary_crossentropy',metrics=['accuracy'])

es = EarlyStopping(monitor='val_acc',mode='max' ,patience=5, min_delta=0.0001,verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_acc', factor=0.2,patience=2,min_lr=0.00001)
model.fit([train_video,train_audio,train_text],Train_labels_surprise,512,epochs=100,validation_split=0.1,callbacks=[es,reduce_lr],
         class_weight=dict(enumerate(class_weight)))


y_pred = (model.predict([test_video,test_audio,test_text])>0.5).astype("float")
y_true = Test_labels_surprise
cm = confusion_matrix(y_true,y_pred)

p = precision_score(y_true,y_pred)
a = accuracy_score(y_true,y_pred)
r = recall_score(y_true,y_pred)
f = f1_score(y_true,y_pred)
print(class_weight)
print(cm)
print("accuracy  :",a)
print("f1 score  :",f)
print("precision :",p)
print("recall    :",r)


TP = cm[1][1]
TN = cm[0][0]
P = Test_labels_surprise.sum()
N = 4832-P
wa = ((TP*N/P) + TN)/(0.02*N)
print("WA        :",wa)
print(classification_report(y_true,y_pred))
model.save("LF_CW_surprise.h5")
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_19 (InputLayer)           (None, 20, 35)       0
# __________________________________________________________________________________________________
# input_20 (InputLayer)           (None, 20, 74)       0
# __________________________________________________________________________________________________
# input_21 (InputLayer)           (None, 20, 300)      0
# __________________________________________________________________________________________________
# lstm_55 (LSTM)                  (None, 20, 64)       25600       input_19[0][0]
# __________________________________________________________________________________________________
# lstm_58 (LSTM)                  (None, 20, 64)       35584       input_20[0][0]
# __________________________________________________________________________________________________
# lstm_61 (LSTM)                  (None, 20, 128)      219648      input_21[0][0]
# __________________________________________________________________________________________________
# lstm_56 (LSTM)                  (None, 20, 32)       12416       lstm_55[0][0]
# __________________________________________________________________________________________________
# lstm_59 (LSTM)                  (None, 20, 32)       12416       lstm_58[0][0]
# __________________________________________________________________________________________________
# lstm_62 (LSTM)                  (None, 20, 64)       49408       lstm_61[0][0]
# __________________________________________________________________________________________________
# lstm_57 (LSTM)                  (None, 32)           8320        lstm_56[0][0]
# __________________________________________________________________________________________________
# lstm_60 (LSTM)                  (None, 32)           8320        lstm_59[0][0]
# __________________________________________________________________________________________________
# lstm_63 (LSTM)                  (None, 32)           12416       lstm_62[0][0]
# __________________________________________________________________________________________________
# dense_31 (Dense)                (None, 32)           1056        lstm_57[0][0]
# __________________________________________________________________________________________________
# dense_32 (Dense)                (None, 32)           1056        lstm_60[0][0]
# __________________________________________________________________________________________________
# dense_33 (Dense)                (None, 32)           1056        lstm_63[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 96)           0           dense_31[0][0]
#                                                                  dense_32[0][0]
#                                                                  dense_33[0][0]
# __________________________________________________________________________________________________
# dense_34 (Dense)                (None, 32)           3104        concatenate_7[0][0]
# __________________________________________________________________________________________________
# dense_35 (Dense)                (None, 1)            33          dense_34[0][0]
# ==================================================================================================
# Total params: 390,433
# Trainable params: 390,433
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Train on 13761 samples, validate on 1529 samples
# Epoch 1/100
# 13761/13761 [==============================] - 25s 2ms/step - loss: 0.6755 - acc: 0.4727 - val_loss: 0.6350 - val_acc: 0.6141
# Epoch 2/100
# 13761/13761 [==============================] - 12s 867us/step - loss: 0.6493 - acc: 0.6142 - val_loss: 0.6325 - val_acc: 0.5572
# Epoch 3/100
# 13761/13761 [==============================] - 12s 852us/step - loss: 0.6311 - acc: 0.6161 - val_loss: 0.6375 - val_acc: 0.6200
# Epoch 4/100
# 13761/13761 [==============================] - 12s 849us/step - loss: 0.6167 - acc: 0.6194 - val_loss: 0.6638 - val_acc: 0.4029
# Epoch 5/100
# 13761/13761 [==============================] - 12s 855us/step - loss: 0.5932 - acc: 0.6351 - val_loss: 0.6737 - val_acc: 0.6024
# Epoch 6/100
# 13761/13761 [==============================] - 12s 871us/step - loss: 0.5444 - acc: 0.6847 - val_loss: 0.6797 - val_acc: 0.6619
# Epoch 7/100
# 13761/13761 [==============================] - 12s 856us/step - loss: 0.5246 - acc: 0.6899 - val_loss: 0.6980 - val_acc: 0.6141
# Epoch 8/100
# 13761/13761 [==============================] - 12s 861us/step - loss: 0.5075 - acc: 0.7014 - val_loss: 0.7297 - val_acc: 0.6409
# Epoch 9/100
# 13761/13761 [==============================] - 12s 856us/step - loss: 0.4906 - acc: 0.7024 - val_loss: 0.7389 - val_acc: 0.6710
# Epoch 10/100
# 13761/13761 [==============================] - 12s 858us/step - loss: 0.4849 - acc: 0.7089 - val_loss: 0.7396 - val_acc: 0.6664
# Epoch 11/100
# 13761/13761 [==============================] - 12s 863us/step - loss: 0.4810 - acc: 0.7115 - val_loss: 0.7509 - val_acc: 0.6821
# Epoch 12/100
# 13761/13761 [==============================] - 12s 855us/step - loss: 0.4773 - acc: 0.7182 - val_loss: 0.7589 - val_acc: 0.6795
# Epoch 13/100
# 13761/13761 [==============================] - 12s 858us/step - loss: 0.4734 - acc: 0.7122 - val_loss: 0.7732 - val_acc: 0.6933
# Epoch 14/100
# 13761/13761 [==============================] - 12s 848us/step - loss: 0.4714 - acc: 0.7260 - val_loss: 0.7695 - val_acc: 0.6730
# Epoch 15/100
# 13761/13761 [==============================] - 12s 862us/step - loss: 0.4670 - acc: 0.7231 - val_loss: 0.7777 - val_acc: 0.6671
# Epoch 16/100
# 13761/13761 [==============================] - 12s 869us/step - loss: 0.4631 - acc: 0.7223 - val_loss: 0.7830 - val_acc: 0.6776
# Epoch 17/100
# 13761/13761 [==============================] - 12s 861us/step - loss: 0.4621 - acc: 0.7233 - val_loss: 0.7844 - val_acc: 0.6697
# Epoch 18/100
# 13761/13761 [==============================] - 12s 854us/step - loss: 0.4613 - acc: 0.7242 - val_loss: 0.7857 - val_acc: 0.6743
# Epoch 00018: early stopping
# [0.55689103 4.8943662 ]
# [[2908 1445]
#  [ 239  240]]
# accuracy  : 0.6514900662251656
# f1 score  : 0.22181146025878004
# precision : 0.142433234421365
# recall    : 0.5010438413361169
# WA        : 58.45444338773394
#               precision    recall  f1-score   support
#
#            0       0.92      0.67      0.78      4353
#            1       0.14      0.50      0.22       479
#
#     accuracy                           0.65      4832
#    macro avg       0.53      0.58      0.50      4832
# weighted avg       0.85      0.65      0.72      4832

# %%
from sklearn.utils import class_weight
class_weight = class_weight.compute_class_weight('balanced',np.unique(Train_labels_disgust.squeeze()),Train_labels_disgust.squeeze())

i_v = Input(shape=(20,35))
i_a = Input(shape=(20,74))
i_t = Input(shape=(20,300))

v = LSTM(64,return_sequences = True)(i_v)
v = LSTM(32,return_sequences = True)(v)
v = LSTM(32,return_sequences = False)(v)
v = Dense(32,activation='relu')(v)

a = LSTM(64,return_sequences = True)(i_a)
a = LSTM(32,return_sequences = True)(a)
a = LSTM(32,return_sequences = False)(a)
a = Dense(32,activation='relu')(a)

t = LSTM(128,return_sequences = True)(i_t)
t = LSTM(64,return_sequences = True)(t)
t = LSTM(32,return_sequences = False)(t)
t = Dense(32,activation='relu')(t)

merge = concatenate([v,a,t])
y = Dense(32,activation='relu')(merge)
y = Dense(1,activation='sigmoid')(y)

model = Model([i_v,i_a,i_t],y)
print(model.summary())
model.compile('adam','binary_crossentropy',metrics=['accuracy'])

es = EarlyStopping(monitor='val_acc',mode='max' ,patience=5, min_delta=0.0001,verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_acc', factor=0.2,patience=2,min_lr=0.00001)
model.fit([train_video,train_audio,train_text],Train_labels_disgust,512,epochs=100,validation_split=0.1,callbacks=[es,reduce_lr],
         class_weight=dict(enumerate(class_weight)))


y_pred = (model.predict([test_video,test_audio,test_text])>0.5).astype("float")
y_true = Test_labels_disgust
cm = confusion_matrix(y_true,y_pred)

p = precision_score(y_true,y_pred)
a = accuracy_score(y_true,y_pred)
r = recall_score(y_true,y_pred)
f = f1_score(y_true,y_pred)
print(class_weight)
print(cm)
print("accuracy  :",a)
print("f1 score  :",f)
print("precision :",p)
print("recall    :",r)


TP = cm[1][1]
TN = cm[0][0]
P = Test_labels_disgust.sum()
N = 4832-P
wa = ((TP*N/P) + TN)/(0.02*N)
print("WA        :",wa)
print(classification_report(y_true,y_pred))
model.save("LF_CW_disgust.h5")
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_22 (InputLayer)           (None, 20, 35)       0
# __________________________________________________________________________________________________
# input_23 (InputLayer)           (None, 20, 74)       0
# __________________________________________________________________________________________________
# input_24 (InputLayer)           (None, 20, 300)      0
# __________________________________________________________________________________________________
# lstm_64 (LSTM)                  (None, 20, 64)       25600       input_22[0][0]
# __________________________________________________________________________________________________
# lstm_67 (LSTM)                  (None, 20, 64)       35584       input_23[0][0]
# __________________________________________________________________________________________________
# lstm_70 (LSTM)                  (None, 20, 128)      219648      input_24[0][0]
# __________________________________________________________________________________________________
# lstm_65 (LSTM)                  (None, 20, 32)       12416       lstm_64[0][0]
# __________________________________________________________________________________________________
# lstm_68 (LSTM)                  (None, 20, 32)       12416       lstm_67[0][0]
# __________________________________________________________________________________________________
# lstm_71 (LSTM)                  (None, 20, 64)       49408       lstm_70[0][0]
# __________________________________________________________________________________________________
# lstm_66 (LSTM)                  (None, 32)           8320        lstm_65[0][0]
# __________________________________________________________________________________________________
# lstm_69 (LSTM)                  (None, 32)           8320        lstm_68[0][0]
# __________________________________________________________________________________________________
# lstm_72 (LSTM)                  (None, 32)           12416       lstm_71[0][0]
# __________________________________________________________________________________________________
# dense_36 (Dense)                (None, 32)           1056        lstm_66[0][0]
# __________________________________________________________________________________________________
# dense_37 (Dense)                (None, 32)           1056        lstm_69[0][0]
# __________________________________________________________________________________________________
# dense_38 (Dense)                (None, 32)           1056        lstm_72[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 96)           0           dense_36[0][0]
#                                                                  dense_37[0][0]
#                                                                  dense_38[0][0]
# __________________________________________________________________________________________________
# dense_39 (Dense)                (None, 32)           3104        concatenate_8[0][0]
# __________________________________________________________________________________________________
# dense_40 (Dense)                (None, 1)            33          dense_39[0][0]
# ==================================================================================================
# Total params: 390,433
# Trainable params: 390,433
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Train on 13761 samples, validate on 1529 samples
# Epoch 1/100
# 13761/13761 [==============================] - 26s 2ms/step - loss: 0.6340 - acc: 0.7170 - val_loss: 0.5477 - val_acc: 0.7358
# Epoch 2/100
# 13761/13761 [==============================] - 12s 863us/step - loss: 0.5726 - acc: 0.6888 - val_loss: 0.5288 - val_acc: 0.7384
# Epoch 3/100
# 13761/13761 [==============================] - 12s 864us/step - loss: 0.5481 - acc: 0.7064 - val_loss: 0.5388 - val_acc: 0.6396
# Epoch 4/100
# 13761/13761 [==============================] - 12s 859us/step - loss: 0.5335 - acc: 0.7039 - val_loss: 0.5333 - val_acc: 0.6880
# Epoch 5/100
# 13761/13761 [==============================] - 12s 860us/step - loss: 0.5088 - acc: 0.7247 - val_loss: 0.5371 - val_acc: 0.7469
# Epoch 6/100
# 13761/13761 [==============================] - 12s 858us/step - loss: 0.4971 - acc: 0.7332 - val_loss: 0.5363 - val_acc: 0.7305
# Epoch 7/100
# 13761/13761 [==============================] - 12s 860us/step - loss: 0.4894 - acc: 0.7364 - val_loss: 0.5512 - val_acc: 0.7436
# Epoch 8/100
# 13761/13761 [==============================] - 12s 861us/step - loss: 0.4801 - acc: 0.7412 - val_loss: 0.5478 - val_acc: 0.7338
# Epoch 9/100
# 13761/13761 [==============================] - 12s 861us/step - loss: 0.4776 - acc: 0.7440 - val_loss: 0.5463 - val_acc: 0.7286
# Epoch 10/100
# 13761/13761 [==============================] - 12s 860us/step - loss: 0.4757 - acc: 0.7409 - val_loss: 0.5484 - val_acc: 0.7312
# Epoch 00010: early stopping
# [0.60819411 2.81066176]
# [[2688 1222]
#  [ 234  688]]
# accuracy  : 0.6986754966887417
# f1 score  : 0.48587570621468923
# precision : 0.36020942408376966
# recall    : 0.7462039045553145
# WA        : 71.68359676229258
#               precision    recall  f1-score   support
#
#            0       0.92      0.69      0.79      3910
#            1       0.36      0.75      0.49       922
#
#     accuracy                           0.70      4832
#    macro avg       0.64      0.72      0.64      4832
# weighted avg       0.81      0.70      0.73      4832

# %%
files.download("LF_CW_happy.h5")
files.download("LF_CW_angry.h5")
files.download("LF_CW_sad.h5")
files.download("LF_CW_fear.h5")
files.download("LF_CW_surprise.h5")
files.download("LF_CW_disgust.h5")
