# %%
# !git clone "https://github.com/convman/Multimodal.git"
# Out:
# Cloning into 'Multimodal'...
# remote: Enumerating objects: 38, done.
# remote: Counting objects: 100% (38/38), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 613 (delta 3), reused 0 (delta 0), pack-reused 575
# Receiving objects: 100% (613/613), 1.10 GiB | 14.47 MiB/s, done.
# Resolving deltas: 100% (205/205), done.
# Checking out files: 100% (360/360), done.

# %%
# !git pull
# Out:
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 4 (delta 3), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (4/4), done.
# From https://github.com/convman/Multimodal
#    4d59ba8..77912dc  master     -> origin/master
# Updating 4d59ba8..77912dc
# error: Your local changes to the following files would be overwritten by merge:
# 	data/dataset_download.sh
# Please commit your changes or stash them before you merge.
# Aborting

# %%
cd Multimodal/
# Out:
# /content/Multimodal

# %%
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/seq_length_20/data/audio_test.h5"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/seq_length_20/data/audio_train.h5"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/seq_length_20/data/text_test_emb.h5"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/seq_length_20/data/text_train_emb.h5"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/seq_length_20/data/video_test.h5"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/seq_length_20/data/video_train.h5"

# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/seq_length_20/labels/mosi2uni_Test_labels_2class.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/seq_length_20/labels/mosi2uni_Test_labels_5class.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/seq_length_20/labels/mosi2uni_Test_labels_7class.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/seq_length_20/labels/mosi2uni_Test_labels_angry.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/seq_length_20/labels/mosi2uni_Test_labels_disgust.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/seq_length_20/labels/mosi2uni_Test_labels_fear.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/seq_length_20/labels/mosi2uni_Test_labels_happy.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/seq_length_20/labels/mosi2uni_Test_labels_sad.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/seq_length_20/labels/mosi2uni_Test_labels_surprise.csv"

# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/seq_length_20/labels/mosi2uni_Train_labels_2class.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/seq_length_20/labels/mosi2uni_Train_labels_5class.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/seq_length_20/labels/mosi2uni_Train_labels_7class.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/seq_length_20/labels/mosi2uni_Train_labels_angry.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/seq_length_20/labels/mosi2uni_Train_labels_disgust.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/seq_length_20/labels/mosi2uni_Train_labels_fear.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/seq_length_20/labels/mosi2uni_Train_labels_happy.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/seq_length_20/labels/mosi2uni_Train_labels_sad.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/seq_length_20/labels/mosi2uni_Train_labels_surprise.csv"

# %%
import pandas as pd
import numpy as np
import h5py
from sklearn.metrics import classification_report
from keras.models import load_model
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import *
from sklearn.utils.multiclass import unique_labels
import keras
import tensorflow as tf
from time import time
import scipy
from keras import layers
from google.colab import files	
from sklearn.utils import class_weight
from keras.models import load_model
from keras.models import Model,Sequential,Model
from keras.layers import *
from keras.callbacks import TensorBoard
from keras import callbacks
from keras.callbacks import *
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import h5py

Test_labels_fear = np.array(pd.read_csv("mosi2uni_Test_labels_fear.csv",header=None))
Train_labels_fear = np.array(pd.read_csv("mosi2uni_Train_labels_fear.csv",header=None))

Test_labels_happy = np.array(pd.read_csv("mosi2uni_Test_labels_happy.csv",header=None))
Train_labels_happy = np.array(pd.read_csv("mosi2uni_Train_labels_happy.csv",header=None))

Test_labels_sad = np.array(pd.read_csv("mosi2uni_Test_labels_sad.csv",header=None))
Train_labels_sad = np.array(pd.read_csv("mosi2uni_Train_labels_sad.csv",header=None))

Test_labels_disgust = np.array(pd.read_csv("mosi2uni_Test_labels_disgust.csv",header=None))
Train_labels_disgust = np.array(pd.read_csv("mosi2uni_Train_labels_disgust.csv",header=None))

Test_labels_surprise = np.array(pd.read_csv("mosi2uni_Test_labels_surprise.csv",header=None))
Train_labels_surprise = np.array(pd.read_csv("mosi2uni_Train_labels_surprise.csv",header=None))

Test_labels_angry = np.array(pd.read_csv("mosi2uni_Test_labels_angry.csv",header=None))
Train_labels_angry = np.array(pd.read_csv("mosi2uni_Train_labels_angry.csv",header=None))

train_video = h5py.File("video_train.h5","r")
train_video = np.array(train_video.get('d1'))
test_video = h5py.File("video_test.h5","r")
test_video = np.array(test_video.get('d1'))

train_audio = h5py.File("audio_train.h5","r")
train_audio = np.array(train_audio.get('d1'))
test_audio = h5py.File("audio_test.h5","r")
test_audio = np.array(test_audio.get('d1'))

train_text = h5py.File("text_train_emb.h5","r")
train_text = np.array(train_text.get('d1'))
test_text = h5py.File("text_test_emb.h5","r")
test_text = np.array(test_text.get('d1'))

# %%
def deep_fuse(out):
  o1 = out[0]     
  o2 = out[1]     
  o3 = out[2]     

  x = 1.-o1
  y = 1.-o2
  z = 1.-o3

  return concatenate([o1,o2,o3,x,y,z])

# %%
from sklearn.utils import class_weight
class_weight = class_weight.compute_class_weight('balanced',np.unique(Train_labels_happy.squeeze()),Train_labels_happy.squeeze())

model_audio_happy = load_model("class weight/unimodal/weights/audio_happy.h5")
model_video_happy = load_model("class weight/unimodal/weights/video_happy.h5")
model_text_happy = load_model("class weight/unimodal/weights/text_happy.h5")

i1 = Input(shape=(20,35),name='i1')
i2 = Input(shape=(20,74),name='i2')
i3 = Input(shape=(20,300),name='i3')

o1 = model_video_happy(i1)
o2 = model_audio_happy(i2)
o3 = model_text_happy(i3)

merged = Lambda(deep_fuse)([o1,o2,o3])
y = Dense(32,activation='relu')(merged)
y = Dropout(rate=0.15)(y)
y = Dense(32,activation='relu')(y)
y = Dense(1,activation='sigmoid')(y)

model = Model([i1,i2,i3],y)
print(model.summary())
model.compile('adam','binary_crossentropy',metrics=['accuracy'])

es = EarlyStopping(monitor='val_acc',mode='max' ,patience=5, min_delta=0.0001,verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_acc', factor=0.2,patience=2,min_lr=0.00001)
model.fit([train_video,train_audio,train_text],Train_labels_happy,512,epochs=100,validation_split=0.1,callbacks=[es,reduce_lr],
         class_weight=dict(enumerate(class_weight)))


y_pred = (model.predict([test_video,test_audio,test_text])>0.5).astype("float")
y_true = Test_labels_happy
cm = confusion_matrix(y_true,y_pred)

p = precision_score(y_true,y_pred)
a = accuracy_score(y_true,y_pred)
r = recall_score(y_true,y_pred)
f = f1_score(y_true,y_pred)
print(class_weight)
print(cm)
print("accuracy  :",a)
print("f1 score  :",f)
print("precision :",p)
print("recall    :",r)


TP = cm[1][1]
TN = cm[0][0]
P = Test_labels_happy.sum()
N = 4832-P
wa = ((TP*N/P) + TN)/(0.02*N)
print("WA        :",wa)
print(classification_report(y_true,y_pred))
model.save("DF_CW_happy.h5")
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# i1 (InputLayer)                 (None, 20, 35)       0
# __________________________________________________________________________________________________
# i2 (InputLayer)                 (None, 20, 74)       0
# __________________________________________________________________________________________________
# i3 (InputLayer)                 (None, 20, 300)      0
# __________________________________________________________________________________________________
# model_27 (Model)                (None, 1)            47425       i1[0][0]
# __________________________________________________________________________________________________
# model_2 (Model)                 (None, 1)            57409       i2[0][0]
# ...

# %%
from sklearn.utils import class_weight
class_weight = class_weight.compute_class_weight('balanced',np.unique(Train_labels_angry.squeeze()),Train_labels_angry.squeeze())

model_audio_angry = load_model("class weight/unimodal/weights/audio_angry.h5")
model_video_angry = load_model("class weight/unimodal/weights/video_angry.h5")
model_text_angry = load_model("class weight/unimodal/weights/text_angry.h5")

i1 = Input(shape=(20,35),name='i1')
i2 = Input(shape=(20,74),name='i2')
i3 = Input(shape=(20,300),name='i3')

o1 = model_video_angry(i1)
o2 = model_audio_angry(i2)
o3 = model_text_angry(i3)

merged = Lambda(deep_fuse)([o1,o2,o3])
y = Dense(32,activation='relu')(merged)
y = Dropout(rate=0.15)(y)
y = Dense(32,activation='relu')(y)
y = Dense(1,activation='sigmoid')(y)

model = Model([i1,i2,i3],y)
print(model.summary())
model.compile('adam','binary_crossentropy',metrics=['accuracy'])

es = EarlyStopping(monitor='val_acc',mode='max' ,patience=5, min_delta=0.0001,verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_acc', factor=0.2,patience=2,min_lr=0.00001)
model.fit([train_video,train_audio,train_text],Train_labels_angry,512,epochs=100,validation_split=0.1,callbacks=[es,reduce_lr],
         class_weight=dict(enumerate(class_weight)))


y_pred = (model.predict([test_video,test_audio,test_text])>0.5).astype("float")
y_true = Test_labels_angry
cm = confusion_matrix(y_true,y_pred)

p = precision_score(y_true,y_pred)
a = accuracy_score(y_true,y_pred)
r = recall_score(y_true,y_pred)
f = f1_score(y_true,y_pred)
print(class_weight)
print(cm)
print("accuracy  :",a)
print("f1 score  :",f)
print("precision :",p)
print("recall    :",r)


TP = cm[1][1]
TN = cm[0][0]
P = Test_labels_angry.sum()
N = 4832-P
wa = ((TP*N/P) + TN)/(0.02*N)
print("WA        :",wa)
print(classification_report(y_true,y_pred))
model.save("DF_CW_angry.h5")
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# i1 (InputLayer)                 (None, 20, 35)       0
# __________________________________________________________________________________________________
# i2 (InputLayer)                 (None, 20, 74)       0
# __________________________________________________________________________________________________
# i3 (InputLayer)                 (None, 20, 300)      0
# __________________________________________________________________________________________________
# model_28 (Model)                (None, 1)            107521      i1[0][0]
# __________________________________________________________________________________________________
# model_4 (Model)                 (None, 1)            57409       i2[0][0]
# ...

# %%
from sklearn.utils import class_weight
class_weight = class_weight.compute_class_weight('balanced',np.unique(Train_labels_sad.squeeze()),Train_labels_sad.squeeze())

model_audio_sad = load_model("class weight/unimodal/weights/audio_sad.h5")
model_video_sad = load_model("class weight/unimodal/weights/video_sad.h5")
model_text_sad = load_model("class weight/unimodal/weights/text_sad.h5")

i1 = Input(shape=(20,35),name='i1')
i2 = Input(shape=(20,74),name='i2')
i3 = Input(shape=(20,300),name='i3')

o1 = model_video_sad(i1)
o2 = model_audio_sad(i2)
o3 = model_text_sad(i3)

merged = Lambda(deep_fuse)([o1,o2,o3])
y = Dense(32,activation='relu')(merged)
y = Dropout(rate=0.15)(y)
y = Dense(32,activation='relu')(y)
y = Dense(1,activation='sigmoid')(y)

model = Model([i1,i2,i3],y)
print(model.summary())
model.compile('adam','binary_crossentropy',metrics=['accuracy'])

es = EarlyStopping(monitor='val_acc',mode='max' ,patience=5, min_delta=0.0001,verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_acc', factor=0.2,patience=2,min_lr=0.00001)
model.fit([train_video,train_audio,train_text],Train_labels_sad,512,epochs=100,validation_split=0.1,callbacks=[es,reduce_lr],
         class_weight=dict(enumerate(class_weight)))


y_pred = (model.predict([test_video,test_audio,test_text])>0.5).astype("float")
y_true = Test_labels_sad
cm = confusion_matrix(y_true,y_pred)

p = precision_score(y_true,y_pred)
a = accuracy_score(y_true,y_pred)
r = recall_score(y_true,y_pred)
f = f1_score(y_true,y_pred)
print(class_weight)
print(cm)
print("accuracy  :",a)
print("f1 score  :",f)
print("precision :",p)
print("recall    :",r)


TP = cm[1][1]
TN = cm[0][0]
P = Test_labels_sad.sum()
N = 4832-P
wa = ((TP*N/P) + TN)/(0.02*N)
print("WA        :",wa)
print(classification_report(y_true,y_pred))
model.save("DF_CW_sad.h5")
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# i1 (InputLayer)                 (None, 20, 35)       0
# __________________________________________________________________________________________________
# i2 (InputLayer)                 (None, 20, 74)       0
# __________________________________________________________________________________________________
# i3 (InputLayer)                 (None, 20, 300)      0
# __________________________________________________________________________________________________
# model_29 (Model)                (None, 1)            107521      i1[0][0]
# __________________________________________________________________________________________________
# model_5 (Model)                 (None, 1)            57409       i2[0][0]
# ...

# %%
from sklearn.utils import class_weight
class_weight = class_weight.compute_class_weight('balanced',np.unique(Train_labels_fear.squeeze()),Train_labels_fear.squeeze())

model_audio_fear = load_model("class weight/unimodal/weights/audio_fear.h5")
model_video_fear = load_model("class weight/unimodal/weights/video_fear.h5")
model_text_fear = load_model("class weight/unimodal/weights/text_fear.h5")

i1 = Input(shape=(20,35),name='i1')
i2 = Input(shape=(20,74),name='i2')
i3 = Input(shape=(20,300),name='i3')

o1 = model_video_fear(i1)
o2 = model_audio_fear(i2)
o3 = model_text_fear(i3)

merged = Lambda(deep_fuse)([o1,o2,o3])
y = Dense(32,activation='relu')(merged)
y = Dropout(rate=0.15)(y)
y = Dense(32,activation='relu')(y)
y = Dense(1,activation='sigmoid')(y)

model = Model([i1,i2,i3],y)
print(model.summary())
model.compile('adam','binary_crossentropy',metrics=['accuracy'])

es = EarlyStopping(monitor='val_acc',mode='max' ,patience=5, min_delta=0.0001,verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_acc', factor=0.2,patience=2,min_lr=0.00001)
model.fit([train_video,train_audio,train_text],Train_labels_fear,512,epochs=100,validation_split=0.1,callbacks=[es,reduce_lr],
         class_weight=dict(enumerate(class_weight)))


y_pred = (model.predict([test_video,test_audio,test_text])>0.5).astype("float")
y_true = Test_labels_fear
cm = confusion_matrix(y_true,y_pred)

p = precision_score(y_true,y_pred)
a = accuracy_score(y_true,y_pred)
r = recall_score(y_true,y_pred)
f = f1_score(y_true,y_pred)
print(class_weight)
print(cm)
print("accuracy  :",a)
print("f1 score  :",f)
print("precision :",p)
print("recall    :",r)


TP = cm[1][1]
TN = cm[0][0]
P = Test_labels_fear.sum()
N = 4832-P
wa = ((TP*N/P) + TN)/(0.02*N)
print("WA        :",wa)
print(classification_report(y_true,y_pred))
model.save("DF_CW_fear.h5")
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# i1 (InputLayer)                 (None, 20, 35)       0
# __________________________________________________________________________________________________
# i2 (InputLayer)                 (None, 20, 74)       0
# __________________________________________________________________________________________________
# i3 (InputLayer)                 (None, 20, 300)      0
# __________________________________________________________________________________________________
# model_30 (Model)                (None, 1)            107521      i1[0][0]
# __________________________________________________________________________________________________
# model_3 (Model)                 (None, 1)            57409       i2[0][0]
# ...

# %%
from sklearn.utils import class_weight
class_weight = class_weight.compute_class_weight('balanced',np.unique(Train_labels_disgust.squeeze()),Train_labels_disgust.squeeze())

model_audio_disgust = load_model("class weight/unimodal/weights/audio_disgust.h5")
model_video_disgust = load_model("class weight/unimodal/weights/video_disgust.h5")
model_text_disgust = load_model("class weight/unimodal/weights/text_disgust.h5")

i1 = Input(shape=(20,35),name='i1')
i2 = Input(shape=(20,74),name='i2')
i3 = Input(shape=(20,300),name='i3')

o1 = model_video_disgust(i1)
o2 = model_audio_disgust(i2)
o3 = model_text_disgust(i3)

merged = Lambda(deep_fuse)([o1,o2,o3])
y = Dense(32,activation='relu')(merged)
y = Dropout(rate=0.15)(y)
y = Dense(32,activation='relu')(y)
y = Dense(1,activation='sigmoid')(y)

model = Model([i1,i2,i3],y)
print(model.summary())
model.compile('adam','binary_crossentropy',metrics=['accuracy'])

es = EarlyStopping(monitor='val_acc',mode='max' ,patience=5, min_delta=0.0001,verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_acc', factor=0.2,patience=2,min_lr=0.00001)
model.fit([train_video,train_audio,train_text],Train_labels_disgust,512,epochs=100,validation_split=0.1,callbacks=[es,reduce_lr],
         class_weight=dict(enumerate(class_weight)))


y_pred = (model.predict([test_video,test_audio,test_text])>0.5).astype("float")
y_true = Test_labels_disgust
cm = confusion_matrix(y_true,y_pred)

p = precision_score(y_true,y_pred)
a = accuracy_score(y_true,y_pred)
r = recall_score(y_true,y_pred)
f = f1_score(y_true,y_pred)
print(class_weight)
print(cm)
print("accuracy  :",a)
print("f1 score  :",f)
print("precision :",p)
print("recall    :",r)


TP = cm[1][1]
TN = cm[0][0]
P = Test_labels_disgust.sum()
N = 4832-P
wa = ((TP*N/P) + TN)/(0.02*N)
print("WA        :",wa)
print(classification_report(y_true,y_pred))
model.save("DF_CW_disgust.h5")
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# i1 (InputLayer)                 (None, 20, 35)       0
# __________________________________________________________________________________________________
# i2 (InputLayer)                 (None, 20, 74)       0
# __________________________________________________________________________________________________
# i3 (InputLayer)                 (None, 20, 300)      0
# __________________________________________________________________________________________________
# model_31 (Model)                (None, 1)            107521      i1[0][0]
# __________________________________________________________________________________________________
# model_6 (Model)                 (None, 1)            57409       i2[0][0]
# ...

# %%
from sklearn.utils import class_weight
class_weight = class_weight.compute_class_weight('balanced',np.unique(Train_labels_surprise.squeeze()),Train_labels_surprise.squeeze())

model_audio_surprise = load_model("class weight/unimodal/weights/audio_surprise.h5")
model_video_surprise = load_model("class weight/unimodal/weights/video_surprise.h5")
model_text_surprise = load_model("class weight/unimodal/weights/text_surprise.h5")

i1 = Input(shape=(20,35),name='i1')
i2 = Input(shape=(20,74),name='i2')
i3 = Input(shape=(20,300),name='i3')

o1 = model_video_surprise(i1)
o2 = model_audio_surprise(i2)
o3 = model_text_surprise(i3)

merged = Lambda(deep_fuse)([o1,o2,o3])
y = Dense(32,activation='relu')(merged)
y = Dropout(rate=0.15)(y)
y = Dense(32,activation='relu')(y)
y = Dense(1,activation='sigmoid')(y)

model = Model([i1,i2,i3],y)
print(model.summary())
model.compile('adam','binary_crossentropy',metrics=['accuracy'])

es = EarlyStopping(monitor='val_acc',mode='max' ,patience=5, min_delta=0.0001,verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_acc', factor=0.2,patience=2,min_lr=0.00001)
model.fit([train_video,train_audio,train_text],Train_labels_surprise,512,epochs=100,validation_split=0.1,callbacks=[es,reduce_lr],
         class_weight=dict(enumerate(class_weight)))


y_pred = (model.predict([test_video,test_audio,test_text])>0.5).astype("float")
y_true = Test_labels_surprise
cm = confusion_matrix(y_true,y_pred)

p = precision_score(y_true,y_pred)
a = accuracy_score(y_true,y_pred)
r = recall_score(y_true,y_pred)
f = f1_score(y_true,y_pred)
print(class_weight)
print(cm)
print("accuracy  :",a)
print("f1 score  :",f)
print("precision :",p)
print("recall    :",r)


TP = cm[1][1]
TN = cm[0][0]
P = Test_labels_surprise.sum()
N = 4832-P
wa = ((TP*N/P) + TN)/(0.02*N)
print("WA        :",wa)
print(classification_report(y_true,y_pred))
model.save("DF_CW_surprise.h5")
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# i1 (InputLayer)                 (None, 20, 35)       0
# __________________________________________________________________________________________________
# i2 (InputLayer)                 (None, 20, 74)       0
# __________________________________________________________________________________________________
# i3 (InputLayer)                 (None, 20, 300)      0
# __________________________________________________________________________________________________
# model_32 (Model)                (None, 1)            107521      i1[0][0]
# __________________________________________________________________________________________________
# model_7 (Model)                 (None, 1)            57409       i2[0][0]
# ...

# %%
files.download("DF_CW_happy.h5")
files.download("DF_CW_angry.h5")
files.download("DF_CW_sad.h5")
files.download("DF_CW_fear.h5")
files.download("DF_CW_surprise.h5")
files.download("DF_CW_disgust.h5")
