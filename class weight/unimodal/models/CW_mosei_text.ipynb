# %%
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/data/audio_test.h5"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/data/audio_train.h5"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/data/text_test_emb.h5"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/data/text_train_emb.h5"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/data/video_test.h5"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/data/video_train.h5"

# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Test_labels_2class.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Test_labels_5class.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Test_labels_7class.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Test_labels_angry.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Test_labels_disgust.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Test_labels_fear.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Test_labels_happy.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Test_labels_sad.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Test_labels_surprise.csv"

# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Train_labels_2class.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Train_labels_5class.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Train_labels_7class.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Train_labels_angry.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Train_labels_disgust.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Train_labels_fear.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Train_labels_happy.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Train_labels_sad.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Train_labels_surprise.csv"
# Out:
# --2019-07-26 07:57:10--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/data/audio_test.h5
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 57213024 (55M)
# Saving to: ‘audio_test.h5’
#
# audio_test.h5       100%[===================>]  54.56M  27.7MB/s    in 2.0s
#
# 2019-07-26 07:57:13 (27.7 MB/s) - ‘audio_test.h5’ saved [57213024/57213024]
#
# --2019-07-26 07:57:15--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/data/audio_train.h5
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 181035744 (173M)
# Saving to: ‘audio_train.h5’
#
# audio_train.h5      100%[===================>] 172.65M  30.9MB/s    in 5.8s
#
# 2019-07-26 07:57:20 (29.9 MB/s) - ‘audio_train.h5’ saved [181035744/181035744]
#
# --2019-07-26 07:57:22--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/data/text_test_emb.h5
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 231938144 (221M)
# Saving to: ‘text_test_emb.h5’
#
# text_test_emb.h5    100%[===================>] 221.19M  29.7MB/s    in 7.5s
#
# 2019-07-26 07:57:30 (29.5 MB/s) - ‘text_test_emb.h5’ saved [231938144/231938144]
#
# --2019-07-26 07:57:31--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/data/text_train_emb.h5
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 733922144 (700M)
# Saving to: ‘text_train_emb.h5’
#
# text_train_emb.h5   100%[===================>] 699.92M  30.4MB/s    in 23s
#
# 2019-07-26 07:57:54 (30.5 MB/s) - ‘text_train_emb.h5’ saved [733922144/733922144]
#
# --2019-07-26 07:57:56--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/data/video_test.h5
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 27061344 (26M)
# Saving to: ‘video_test.h5’
#
# video_test.h5       100%[===================>]  25.81M  25.0MB/s    in 1.0s
#
# 2019-07-26 07:57:57 (25.0 MB/s) - ‘video_test.h5’ saved [27061344/27061344]
#
# --2019-07-26 07:57:58--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/data/video_train.h5
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 85626144 (82M)
# Saving to: ‘video_train.h5’
#
# video_train.h5      100%[===================>]  81.66M  29.2MB/s    in 2.8s
#
# 2019-07-26 07:58:01 (29.2 MB/s) - ‘video_train.h5’ saved [85626144/85626144]
#
# --2019-07-26 07:58:03--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Test_labels_2class.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9664 (9.4K) [text/csv]
# Saving to: ‘mosi2uni_Test_labels_2class.csv’
#
# mosi2uni_Test_label 100%[===================>]   9.44K  --.-KB/s    in 0s
#
# 2019-07-26 07:58:03 (23.7 MB/s) - ‘mosi2uni_Test_labels_2class.csv’ saved [9664/9664]
#
# --2019-07-26 07:58:04--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Test_labels_5class.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9664 (9.4K) [text/csv]
# Saving to: ‘mosi2uni_Test_labels_5class.csv’
#
# mosi2uni_Test_label 100%[===================>]   9.44K  --.-KB/s    in 0s
#
# 2019-07-26 07:58:04 (29.2 MB/s) - ‘mosi2uni_Test_labels_5class.csv’ saved [9664/9664]
#
# --2019-07-26 07:58:07--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Test_labels_7class.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9664 (9.4K) [text/csv]
# Saving to: ‘mosi2uni_Test_labels_7class.csv’
#
# mosi2uni_Test_label 100%[===================>]   9.44K  --.-KB/s    in 0s
#
# 2019-07-26 07:58:07 (24.6 MB/s) - ‘mosi2uni_Test_labels_7class.csv’ saved [9664/9664]
#
# --2019-07-26 07:58:09--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Test_labels_angry.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9664 (9.4K) [text/csv]
# Saving to: ‘mosi2uni_Test_labels_angry.csv’
#
# mosi2uni_Test_label 100%[===================>]   9.44K  --.-KB/s    in 0s
#
# 2019-07-26 07:58:09 (26.4 MB/s) - ‘mosi2uni_Test_labels_angry.csv’ saved [9664/9664]
#
# --2019-07-26 07:58:11--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Test_labels_disgust.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9664 (9.4K) [text/csv]
# Saving to: ‘mosi2uni_Test_labels_disgust.csv’
#
# mosi2uni_Test_label 100%[===================>]   9.44K  --.-KB/s    in 0s
#
# 2019-07-26 07:58:11 (22.9 MB/s) - ‘mosi2uni_Test_labels_disgust.csv’ saved [9664/9664]
#
# --2019-07-26 07:58:13--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Test_labels_fear.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9664 (9.4K) [text/csv]
# Saving to: ‘mosi2uni_Test_labels_fear.csv’
#
# mosi2uni_Test_label 100%[===================>]   9.44K  --.-KB/s    in 0s
#
# 2019-07-26 07:58:13 (28.9 MB/s) - ‘mosi2uni_Test_labels_fear.csv’ saved [9664/9664]
#
# --2019-07-26 07:58:16--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Test_labels_happy.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9664 (9.4K) [text/csv]
# Saving to: ‘mosi2uni_Test_labels_happy.csv’
#
# mosi2uni_Test_label 100%[===================>]   9.44K  --.-KB/s    in 0s
#
# 2019-07-26 07:58:16 (23.9 MB/s) - ‘mosi2uni_Test_labels_happy.csv’ saved [9664/9664]
#
# --2019-07-26 07:58:18--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Test_labels_sad.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9664 (9.4K) [text/csv]
# Saving to: ‘mosi2uni_Test_labels_sad.csv’
#
# mosi2uni_Test_label 100%[===================>]   9.44K  --.-KB/s    in 0s
#
# 2019-07-26 07:58:18 (19.4 MB/s) - ‘mosi2uni_Test_labels_sad.csv’ saved [9664/9664]
#
# --2019-07-26 07:58:20--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Test_labels_surprise.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9664 (9.4K) [text/csv]
# Saving to: ‘mosi2uni_Test_labels_surprise.csv’
#
# mosi2uni_Test_label 100%[===================>]   9.44K  --.-KB/s    in 0s
#
# 2019-07-26 07:58:20 (25.3 MB/s) - ‘mosi2uni_Test_labels_surprise.csv’ saved [9664/9664]
#
# --2019-07-26 07:58:23--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Train_labels_2class.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 30580 (30K) [text/csv]
# Saving to: ‘mosi2uni_Train_labels_2class.csv’
#
# mosi2uni_Train_labe 100%[===================>]  29.86K  --.-KB/s    in 0.04s
#
# 2019-07-26 07:58:24 (838 KB/s) - ‘mosi2uni_Train_labels_2class.csv’ saved [30580/30580]
#
# --2019-07-26 07:58:26--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Train_labels_5class.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 30580 (30K) [text/csv]
# Saving to: ‘mosi2uni_Train_labels_5class.csv’
#
# mosi2uni_Train_labe 100%[===================>]  29.86K  --.-KB/s    in 0.04s
#
# 2019-07-26 07:58:26 (836 KB/s) - ‘mosi2uni_Train_labels_5class.csv’ saved [30580/30580]
#
# --2019-07-26 07:58:28--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Train_labels_7class.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 30580 (30K) [text/csv]
# Saving to: ‘mosi2uni_Train_labels_7class.csv’
#
# mosi2uni_Train_labe 100%[===================>]  29.86K  --.-KB/s    in 0.04s
#
# 2019-07-26 07:58:28 (828 KB/s) - ‘mosi2uni_Train_labels_7class.csv’ saved [30580/30580]
#
# --2019-07-26 07:58:30--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Train_labels_angry.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 30580 (30K) [text/csv]
# Saving to: ‘mosi2uni_Train_labels_angry.csv’
#
# mosi2uni_Train_labe 100%[===================>]  29.86K  --.-KB/s    in 0.04s
#
# 2019-07-26 07:58:30 (833 KB/s) - ‘mosi2uni_Train_labels_angry.csv’ saved [30580/30580]
#
# --2019-07-26 07:58:32--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Train_labels_disgust.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 30580 (30K) [text/csv]
# Saving to: ‘mosi2uni_Train_labels_disgust.csv’
#
# mosi2uni_Train_labe 100%[===================>]  29.86K  --.-KB/s    in 0.04s
#
# 2019-07-26 07:58:32 (835 KB/s) - ‘mosi2uni_Train_labels_disgust.csv’ saved [30580/30580]
#
# --2019-07-26 07:58:34--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Train_labels_fear.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 30580 (30K) [text/csv]
# Saving to: ‘mosi2uni_Train_labels_fear.csv’
#
# mosi2uni_Train_labe 100%[===================>]  29.86K  --.-KB/s    in 0.04s
#
# 2019-07-26 07:58:34 (838 KB/s) - ‘mosi2uni_Train_labels_fear.csv’ saved [30580/30580]
#
# --2019-07-26 07:58:36--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Train_labels_happy.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 30580 (30K) [text/csv]
# Saving to: ‘mosi2uni_Train_labels_happy.csv’
#
# mosi2uni_Train_labe 100%[===================>]  29.86K  --.-KB/s    in 0.04s
#
# 2019-07-26 07:58:36 (832 KB/s) - ‘mosi2uni_Train_labels_happy.csv’ saved [30580/30580]
#
# --2019-07-26 07:58:39--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Train_labels_sad.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 30580 (30K) [text/csv]
# Saving to: ‘mosi2uni_Train_labels_sad.csv’
#
# mosi2uni_Train_labe 100%[===================>]  29.86K  --.-KB/s    in 0.04s
#
# 2019-07-26 07:58:39 (836 KB/s) - ‘mosi2uni_Train_labels_sad.csv’ saved [30580/30580]
#
# --2019-07-26 07:58:41--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Train_labels_surprise.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 30580 (30K) [text/csv]
# Saving to: ‘mosi2uni_Train_labels_surprise.csv’
#
# mosi2uni_Train_labe 100%[===================>]  29.86K  --.-KB/s    in 0.04s
#
# 2019-07-26 07:58:41 (836 KB/s) - ‘mosi2uni_Train_labels_surprise.csv’ saved [30580/30580]

# %%
import pandas as pd
import numpy as np
import h5py
from sklearn.metrics import classification_report
from keras.models import load_model
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import *
from sklearn.utils.multiclass import unique_labels
import keras
import tensorflow as tf
from time import time
import scipy
from keras import layers
from google.colab import files	
from sklearn.utils import class_weight
from keras.models import load_model
from keras.models import Model,Sequential,Model
from keras.layers import *
from keras.callbacks import TensorBoard
from keras import callbacks
from keras.callbacks import *
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
import pandas as pd
import numpy as np
import h5py

Test_labels_fear = np.array(pd.read_csv("mosi2uni_Test_labels_fear.csv",header=None))
Train_labels_fear = np.array(pd.read_csv("mosi2uni_Train_labels_fear.csv",header=None))

Test_labels_happy = np.array(pd.read_csv("mosi2uni_Test_labels_happy.csv",header=None))
Train_labels_happy = np.array(pd.read_csv("mosi2uni_Train_labels_happy.csv",header=None))

Test_labels_sad = np.array(pd.read_csv("mosi2uni_Test_labels_sad.csv",header=None))
Train_labels_sad = np.array(pd.read_csv("mosi2uni_Train_labels_sad.csv",header=None))

Test_labels_disgust = np.array(pd.read_csv("mosi2uni_Test_labels_disgust.csv",header=None))
Train_labels_disgust = np.array(pd.read_csv("mosi2uni_Train_labels_disgust.csv",header=None))

Test_labels_surprise = np.array(pd.read_csv("mosi2uni_Test_labels_surprise.csv",header=None))
Train_labels_surprise = np.array(pd.read_csv("mosi2uni_Train_labels_surprise.csv",header=None))

Test_labels_angry = np.array(pd.read_csv("mosi2uni_Test_labels_angry.csv",header=None))
Train_labels_angry = np.array(pd.read_csv("mosi2uni_Train_labels_angry.csv",header=None))

X_train = h5py.File("text_train_emb.h5","r")
X_train = np.array(X_train.get('d1'))

X_test = h5py.File("text_test_emb.h5","r")
X_test = np.array(X_test.get('d1'))
print(X_train.shape,X_test.shape)
# Out:
# (15290, 20, 300) (4832, 20, 300)

# %%
from sklearn.utils import class_weight
class_weight = class_weight.compute_class_weight('balanced',np.unique(Train_labels_happy.squeeze()),Train_labels_happy.squeeze())
print(class_weight)

i = Input(shape=(20,300))
x = LSTM(128,return_sequences = True)(i)
x = LSTM(64,return_sequences = True)(x)
x = LSTM(32,return_sequences = False)(x)
x = Dense(32,activation='relu')(x)
x = Dense(1,activation='sigmoid')(x)

model = Model(i,x)
print(model.summary())
model.compile('adam','binary_crossentropy',metrics=['accuracy'])

es = EarlyStopping(monitor='val_acc',mode='max' ,patience=5, min_delta=0.0001,verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_acc', factor=0.2,patience=2,min_lr=0.00001)
model.fit(X_train,Train_labels_happy,512,epochs=100,validation_split=0.1,callbacks=[es,reduce_lr],
         class_weight=dict(enumerate(class_weight)))


y_pred = (model.predict(X_test)>0.5).astype("float")
y_true = Test_labels_happy
cm = confusion_matrix(y_true,y_pred)

p = precision_score(y_true,y_pred)
a = accuracy_score(y_true,y_pred)
r = recall_score(y_true,y_pred)
f = f1_score(y_true,y_pred)
print(cm)
print("accuracy  :",a)
print("f1 score  :",f)
print("precision :",p)
print("recall    :",r)


TP = cm[1][1]
TN = cm[0][0]
P = Test_labels_happy.sum()
N = 4832-P
wa = ((TP*N/P) + TN)/(0.02*N)
print("WA        :",wa)
print(classification_report(y_true,y_pred))
model.save("text_happy.h5")
# Out:
# [1.07027859 0.93838223]
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         (None, 20, 300)           0
# _________________________________________________________________
# lstm_22 (LSTM)               (None, 20, 128)           219648
# _________________________________________________________________
# lstm_23 (LSTM)               (None, 20, 64)            49408
# _________________________________________________________________
# lstm_24 (LSTM)               (None, 32)                12416
# _________________________________________________________________
# dense_15 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dense_16 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 282,561
# Trainable params: 282,561
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 13761 samples, validate on 1529 samples
# Epoch 1/100
# 13761/13761 [==============================] - 8s 571us/step - loss: 0.6744 - acc: 0.5824 - val_loss: 0.6589 - val_acc: 0.6017
# Epoch 2/100
# 13761/13761 [==============================] - 3s 209us/step - loss: 0.6511 - acc: 0.6268 - val_loss: 0.6511 - val_acc: 0.6233
# Epoch 3/100
# 13761/13761 [==============================] - 3s 212us/step - loss: 0.6436 - acc: 0.6284 - val_loss: 0.6488 - val_acc: 0.6344
# Epoch 4/100
# 13761/13761 [==============================] - 3s 213us/step - loss: 0.6398 - acc: 0.6338 - val_loss: 0.6487 - val_acc: 0.6109
# Epoch 5/100
# 13761/13761 [==============================] - 3s 210us/step - loss: 0.6316 - acc: 0.6470 - val_loss: 0.6449 - val_acc: 0.6292
# Epoch 6/100
# 13761/13761 [==============================] - 3s 211us/step - loss: 0.6219 - acc: 0.6576 - val_loss: 0.6440 - val_acc: 0.6292
# Epoch 7/100
# 13761/13761 [==============================] - 3s 212us/step - loss: 0.6195 - acc: 0.6594 - val_loss: 0.6452 - val_acc: 0.6259
# Epoch 8/100
# 13761/13761 [==============================] - 3s 209us/step - loss: 0.6156 - acc: 0.6652 - val_loss: 0.6464 - val_acc: 0.6357
# Epoch 9/100
# 13761/13761 [==============================] - 3s 210us/step - loss: 0.6148 - acc: 0.6655 - val_loss: 0.6461 - val_acc: 0.6285
# Epoch 10/100
# 13761/13761 [==============================] - 3s 210us/step - loss: 0.6139 - acc: 0.6669 - val_loss: 0.6463 - val_acc: 0.6279
# Epoch 11/100
# 13761/13761 [==============================] - 3s 209us/step - loss: 0.6131 - acc: 0.6670 - val_loss: 0.6463 - val_acc: 0.6279
# Epoch 12/100
# 13761/13761 [==============================] - 3s 209us/step - loss: 0.6130 - acc: 0.6675 - val_loss: 0.6464 - val_acc: 0.6252
# Epoch 13/100
# 13761/13761 [==============================] - 3s 210us/step - loss: 0.6127 - acc: 0.6678 - val_loss: 0.6463 - val_acc: 0.6252
# Epoch 00013: early stopping
# [[1547  763]
#  [1027 1495]]
# accuracy  : 0.6295529801324503
# f1 score  : 0.6255230125523012
# precision : 0.6620903454384411
# recall    : 0.5927835051546392
# WA        : 63.12402374258044
#               precision    recall  f1-score   support
#
#            0       0.60      0.67      0.63      2310
#            1       0.66      0.59      0.63      2522
#
#     accuracy                           0.63      4832
#    macro avg       0.63      0.63      0.63      4832
# weighted avg       0.63      0.63      0.63      4832

# %%
from sklearn.utils import class_weight
class_weight = class_weight.compute_class_weight('balanced',np.unique(Train_labels_angry.squeeze()),Train_labels_angry.squeeze())
print(class_weight)

i = Input(shape=(20,300))
x = LSTM(128,return_sequences = True)(i)
x = LSTM(64,return_sequences = True)(x)
x = LSTM(32,return_sequences = False)(x)
x = Dense(32,activation='relu')(x)
x = Dense(1,activation='sigmoid')(x)

model = Model(i,x)
print(model.summary())
model.compile('adam','binary_crossentropy',metrics=['accuracy'])

es = EarlyStopping(monitor='val_acc',mode='max' ,patience=5, min_delta=0.0001,verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_acc', factor=0.2,patience=2,min_lr=0.00001)
model.fit(X_train,Train_labels_angry,512,epochs=100,validation_split=0.1,callbacks=[es,reduce_lr],
         class_weight=dict(enumerate(class_weight)))


y_pred = (model.predict(X_test)>0.5).astype("float")
y_true = Test_labels_angry
cm = confusion_matrix(y_true,y_pred)

p = precision_score(y_true,y_pred)
a = accuracy_score(y_true,y_pred)
r = recall_score(y_true,y_pred)
f = f1_score(y_true,y_pred)
print(cm)
print("accuracy  :",a)
print("f1 score  :",f)
print("precision :",p)
print("recall    :",r)


TP = cm[1][1]
TN = cm[0][0]
P = Test_labels_angry.sum()
N = 4832-P
wa = ((TP*N/P) + TN)/(0.02*N)
print("WA        :",wa)
print(classification_report(y_true,y_pred))
model.save("text_angry.h5")
# Out:
# [0.64531105 2.22044728]
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_9 (InputLayer)         (None, 20, 300)           0
# _________________________________________________________________
# lstm_25 (LSTM)               (None, 20, 128)           219648
# _________________________________________________________________
# lstm_26 (LSTM)               (None, 20, 64)            49408
# _________________________________________________________________
# lstm_27 (LSTM)               (None, 32)                12416
# _________________________________________________________________
# dense_17 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dense_18 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 282,561
# Trainable params: 282,561
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 13761 samples, validate on 1529 samples
# Epoch 1/100
# 13761/13761 [==============================] - 8s 602us/step - loss: 0.6792 - acc: 0.6125 - val_loss: 0.6340 - val_acc: 0.4637
# Epoch 2/100
# 13761/13761 [==============================] - 3s 209us/step - loss: 0.6588 - acc: 0.5883 - val_loss: 0.6096 - val_acc: 0.6455
# Epoch 3/100
# 13761/13761 [==============================] - 3s 207us/step - loss: 0.6499 - acc: 0.6143 - val_loss: 0.6105 - val_acc: 0.6089
# Epoch 4/100
# 13761/13761 [==============================] - 3s 210us/step - loss: 0.6381 - acc: 0.6167 - val_loss: 0.6045 - val_acc: 0.6442
# Epoch 5/100
# 13761/13761 [==============================] - 3s 211us/step - loss: 0.6270 - acc: 0.6388 - val_loss: 0.6143 - val_acc: 0.5814
# Epoch 6/100
# 13761/13761 [==============================] - 3s 210us/step - loss: 0.6204 - acc: 0.6307 - val_loss: 0.6172 - val_acc: 0.5768
# Epoch 7/100
# 13761/13761 [==============================] - 3s 207us/step - loss: 0.6156 - acc: 0.6405 - val_loss: 0.6190 - val_acc: 0.5723
# Epoch 00007: early stopping
# [[2002 1859]
#  [ 258  713]]
# accuracy  : 0.5618791390728477
# f1 score  : 0.402483770815693
# precision : 0.2772161741835148
# recall    : 0.7342945417095778
# WA        : 62.640653011404815
#               precision    recall  f1-score   support
#
#            0       0.89      0.52      0.65      3861
#            1       0.28      0.73      0.40       971
#
#     accuracy                           0.56      4832
#    macro avg       0.58      0.63      0.53      4832
# weighted avg       0.76      0.56      0.60      4832

# %%
from sklearn.utils import class_weight
class_weight = class_weight.compute_class_weight('balanced',np.unique(Train_labels_sad.squeeze()),Train_labels_sad.squeeze())
print(class_weight)

i = Input(shape=(20,300))
x = LSTM(128,return_sequences = True)(i)
x = LSTM(64,return_sequences = True)(x)
x = LSTM(32,return_sequences = False)(x)
x = Dense(32,activation='relu')(x)
x = Dense(1,activation='sigmoid')(x)

model = Model(i,x)
print(model.summary())
model.compile('adam','binary_crossentropy',metrics=['accuracy'])

es = EarlyStopping(monitor='val_acc',mode='max' ,patience=5, min_delta=0.0001,verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_acc', factor=0.2,patience=2,min_lr=0.00001)
model.fit(X_train,Train_labels_sad,512,epochs=100,validation_split=0.1,callbacks=[es,reduce_lr],
         class_weight=dict(enumerate(class_weight)))


y_pred = (model.predict(X_test)>0.5).astype("float")
y_true = Test_labels_sad
cm = confusion_matrix(y_true,y_pred)

p = precision_score(y_true,y_pred)
a = accuracy_score(y_true,y_pred)
r = recall_score(y_true,y_pred)
f = f1_score(y_true,y_pred)
print(cm)
print("accuracy  :",a)
print("f1 score  :",f)
print("precision :",p)
print("recall    :",r)


TP = cm[1][1]
TN = cm[0][0]
P = Test_labels_sad.sum()
N = 4832-P
wa = ((TP*N/P) + TN)/(0.02*N)
print("WA        :",wa)
print(classification_report(y_true,y_pred))
model.save("text_sad.h5")
# Out:
# [0.67155657 1.95724526]
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_10 (InputLayer)        (None, 20, 300)           0
# _________________________________________________________________
# lstm_28 (LSTM)               (None, 20, 128)           219648
# _________________________________________________________________
# lstm_29 (LSTM)               (None, 20, 64)            49408
# _________________________________________________________________
# lstm_30 (LSTM)               (None, 32)                12416
# _________________________________________________________________
# dense_19 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dense_20 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 282,561
# Trainable params: 282,561
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 13761 samples, validate on 1529 samples
# Epoch 1/100
# 13761/13761 [==============================] - 9s 645us/step - loss: 0.6907 - acc: 0.5418 - val_loss: 0.6637 - val_acc: 0.6167
# Epoch 2/100
# 13761/13761 [==============================] - 3s 209us/step - loss: 0.6787 - acc: 0.5965 - val_loss: 0.6616 - val_acc: 0.5847
# Epoch 3/100
# 13761/13761 [==============================] - 3s 207us/step - loss: 0.6707 - acc: 0.5802 - val_loss: 0.6592 - val_acc: 0.6109
# Epoch 4/100
# 13761/13761 [==============================] - 3s 209us/step - loss: 0.6631 - acc: 0.6029 - val_loss: 0.6559 - val_acc: 0.6141
# Epoch 5/100
# 13761/13761 [==============================] - 3s 208us/step - loss: 0.6594 - acc: 0.5989 - val_loss: 0.6579 - val_acc: 0.5670
# Epoch 6/100
# 13761/13761 [==============================] - 3s 209us/step - loss: 0.6559 - acc: 0.6013 - val_loss: 0.6562 - val_acc: 0.5893
# Epoch 00006: early stopping
# [[1941 1557]
#  [ 487  847]]
# accuracy  : 0.5769867549668874
# f1 score  : 0.45318352059925093
# precision : 0.35232945091514145
# recall    : 0.6349325337331334
# WA        : 59.491052072591486
#               precision    recall  f1-score   support
#
#            0       0.80      0.55      0.66      3498
#            1       0.35      0.63      0.45      1334
#
#     accuracy                           0.58      4832
#    macro avg       0.58      0.59      0.55      4832
# weighted avg       0.68      0.58      0.60      4832

# %%
from sklearn.utils import class_weight
class_weight = class_weight.compute_class_weight('balanced',np.unique(Train_labels_fear.squeeze()),Train_labels_fear.squeeze())
print(class_weight)

i = Input(shape=(20,300))
x = LSTM(128,return_sequences = True)(i)
x = LSTM(64,return_sequences = True)(x)
x = LSTM(32,return_sequences = False)(x)
x = Dense(32,activation='relu')(x)
x = Dense(1,activation='sigmoid')(x)

model = Model(i,x)
print(model.summary())
model.compile('adam','binary_crossentropy',metrics=['accuracy'])

es = EarlyStopping(monitor='val_acc',mode='max' ,patience=5, min_delta=0.0001,verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_acc', factor=0.2,patience=2,min_lr=0.00001)
model.fit(X_train,Train_labels_fear,512,epochs=100,validation_split=0.1,callbacks=[es,reduce_lr],
         class_weight=dict(enumerate(class_weight)))


y_pred = (model.predict(X_test)>0.5).astype("float")
y_true = Test_labels_fear
cm = confusion_matrix(y_true,y_pred)

p = precision_score(y_true,y_pred)
a = accuracy_score(y_true,y_pred)
r = recall_score(y_true,y_pred)
f = f1_score(y_true,y_pred)
print(cm)
print("accuracy  :",a)
print("f1 score  :",f)
print("precision :",p)
print("recall    :",r)


TP = cm[1][1]
TN = cm[0][0]
P = Test_labels_fear.sum()
N = 4832-P
wa = ((TP*N/P) + TN)/(0.02*N)
print("WA        :",wa)
print(classification_report(y_true,y_pred))
model.save("text_fear.h5")
# Out:
# [0.54720492 5.79605762]
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_11 (InputLayer)        (None, 20, 300)           0
# _________________________________________________________________
# lstm_31 (LSTM)               (None, 20, 128)           219648
# _________________________________________________________________
# lstm_32 (LSTM)               (None, 20, 64)            49408
# _________________________________________________________________
# lstm_33 (LSTM)               (None, 32)                12416
# _________________________________________________________________
# dense_21 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dense_22 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 282,561
# Trainable params: 282,561
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 13761 samples, validate on 1529 samples
# Epoch 1/100
# 13761/13761 [==============================] - 9s 677us/step - loss: 0.6751 - acc: 0.4820 - val_loss: 0.6884 - val_acc: 0.5154
# Epoch 2/100
# 13761/13761 [==============================] - 3s 208us/step - loss: 0.6463 - acc: 0.6026 - val_loss: 0.6901 - val_acc: 0.4565
# Epoch 3/100
# 13761/13761 [==============================] - 3s 209us/step - loss: 0.6368 - acc: 0.6062 - val_loss: 0.7014 - val_acc: 0.7358
# Epoch 4/100
# 13761/13761 [==============================] - 3s 208us/step - loss: 0.6236 - acc: 0.6385 - val_loss: 0.6957 - val_acc: 0.5971
# Epoch 5/100
# 13761/13761 [==============================] - 3s 207us/step - loss: 0.6102 - acc: 0.6518 - val_loss: 0.6936 - val_acc: 0.5965
# Epoch 6/100
# 13761/13761 [==============================] - 3s 211us/step - loss: 0.5852 - acc: 0.6694 - val_loss: 0.7127 - val_acc: 0.6717
# Epoch 7/100
# 13761/13761 [==============================] - 3s 208us/step - loss: 0.5761 - acc: 0.6890 - val_loss: 0.7392 - val_acc: 0.7155
# Epoch 8/100
# 13761/13761 [==============================] - 3s 209us/step - loss: 0.5661 - acc: 0.6898 - val_loss: 0.7269 - val_acc: 0.6854
# Epoch 00008: early stopping
# [[3143 1357]
#  [ 139  193]]
# accuracy  : 0.6903973509933775
# f1 score  : 0.2051009564293305
# precision : 0.12451612903225806
# recall    : 0.5813253012048193
# WA        : 63.98848728246319
#               precision    recall  f1-score   support
#
#            0       0.96      0.70      0.81      4500
#            1       0.12      0.58      0.21       332
#
#     accuracy                           0.69      4832
#    macro avg       0.54      0.64      0.51      4832
# weighted avg       0.90      0.69      0.77      4832

# %%
from sklearn.utils import class_weight
class_weight = class_weight.compute_class_weight('balanced',np.unique(Train_labels_disgust.squeeze()),Train_labels_disgust.squeeze())
print(class_weight)

i = Input(shape=(20,300))
x = LSTM(128,return_sequences = True)(i)
x = LSTM(64,return_sequences = True)(x)
x = LSTM(32,return_sequences = False)(x)
x = Dense(32,activation='relu')(x)
x = Dense(1,activation='sigmoid')(x)

model = Model(i,x)
print(model.summary())
model.compile('adam','binary_crossentropy',metrics=['accuracy'])

es = EarlyStopping(monitor='val_acc',mode='max' ,patience=5, min_delta=0.0001,verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_acc', factor=0.2,patience=2,min_lr=0.00001)
model.fit(X_train,Train_labels_disgust,512,epochs=100,validation_split=0.1,callbacks=[es,reduce_lr],
         class_weight=dict(enumerate(class_weight)))


y_pred = (model.predict(X_test)>0.5).astype("float")
y_true = Test_labels_disgust
cm = confusion_matrix(y_true,y_pred)

p = precision_score(y_true,y_pred)
a = accuracy_score(y_true,y_pred)
r = recall_score(y_true,y_pred)
f = f1_score(y_true,y_pred)
print(cm)
print("accuracy  :",a)
print("f1 score  :",f)
print("precision :",p)
print("recall    :",r)


TP = cm[1][1]
TN = cm[0][0]
P = Test_labels_disgust.sum()
N = 4832-P
wa = ((TP*N/P) + TN)/(0.02*N)
print("WA        :",wa)
print(classification_report(y_true,y_pred))
model.save("text_disgust.h5")
# Out:
# [0.60819411 2.81066176]
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_12 (InputLayer)        (None, 20, 300)           0
# _________________________________________________________________
# lstm_34 (LSTM)               (None, 20, 128)           219648
# _________________________________________________________________
# lstm_35 (LSTM)               (None, 20, 64)            49408
# _________________________________________________________________
# lstm_36 (LSTM)               (None, 32)                12416
# _________________________________________________________________
# dense_23 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dense_24 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 282,561
# Trainable params: 282,561
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 13761 samples, validate on 1529 samples
# Epoch 1/100
# 13761/13761 [==============================] - 10s 706us/step - loss: 0.6550 - acc: 0.6284 - val_loss: 0.5854 - val_acc: 0.7325
# Epoch 2/100
# 13761/13761 [==============================] - 3s 207us/step - loss: 0.6062 - acc: 0.6542 - val_loss: 0.5572 - val_acc: 0.6848
# Epoch 3/100
# 13761/13761 [==============================] - 3s 208us/step - loss: 0.5883 - acc: 0.6610 - val_loss: 0.5601 - val_acc: 0.6364
# Epoch 4/100
# 13761/13761 [==============================] - 3s 210us/step - loss: 0.5737 - acc: 0.6680 - val_loss: 0.5518 - val_acc: 0.6795
# Epoch 5/100
# 13761/13761 [==============================] - 3s 208us/step - loss: 0.5682 - acc: 0.6738 - val_loss: 0.5494 - val_acc: 0.6671
# Epoch 6/100
# 13761/13761 [==============================] - 3s 211us/step - loss: 0.5646 - acc: 0.6750 - val_loss: 0.5495 - val_acc: 0.6664
# Epoch 00006: early stopping
# [[2295 1615]
#  [ 198  724]]
# accuracy  : 0.6247930463576159
# f1 score  : 0.444035571910457
# precision : 0.3095339888841385
# recall    : 0.7852494577006508
# WA        : 68.61029897198907
#               precision    recall  f1-score   support
#
#            0       0.92      0.59      0.72      3910
#            1       0.31      0.79      0.44       922
#
#     accuracy                           0.62      4832
#    macro avg       0.62      0.69      0.58      4832
# weighted avg       0.80      0.62      0.66      4832

# %%
from sklearn.utils import class_weight
class_weight = class_weight.compute_class_weight('balanced',np.unique(Train_labels_surprise.squeeze()),Train_labels_surprise.squeeze())
print(class_weight)

i = Input(shape=(20,300))
x = LSTM(128,return_sequences = True)(i)
x = LSTM(64,return_sequences = True)(x)
x = LSTM(32,return_sequences = False)(x)
x = Dense(32,activation='relu')(x)
x = Dense(1,activation='sigmoid')(x)

model = Model(i,x)
print(model.summary())
model.compile('adam','binary_crossentropy',metrics=['accuracy'])

es = EarlyStopping(monitor='val_acc',mode='max' ,patience=5, min_delta=0.0001,verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_acc', factor=0.2,patience=2,min_lr=0.00001)
model.fit(X_train,Train_labels_surprise,512,epochs=100,validation_split=0.1,callbacks=[es,reduce_lr],
         class_weight=dict(enumerate(class_weight)))


y_pred = (model.predict(X_test)>0.5).astype("float")
y_true = Test_labels_surprise
cm = confusion_matrix(y_true,y_pred)

p = precision_score(y_true,y_pred)
a = accuracy_score(y_true,y_pred)
r = recall_score(y_true,y_pred)
f = f1_score(y_true,y_pred) 
print(cm)
print("accuracy  :",a)
print("f1 score  :",f)
print("precision :",p)
print("recall    :",r)


TP = cm[1][1]
TN = cm[0][0]
P = Test_labels_surprise.sum()
N = 4832-P
wa = ((TP*N/P) + TN)/(0.02*N)
print("WA        :",wa)
print(classification_report(y_true,y_pred))
model.save("text_surprise.h5")
# Out:
# [0.55689103 4.8943662 ]
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_13 (InputLayer)        (None, 20, 300)           0
# _________________________________________________________________
# lstm_37 (LSTM)               (None, 20, 128)           219648
# _________________________________________________________________
# lstm_38 (LSTM)               (None, 20, 64)            49408
# _________________________________________________________________
# lstm_39 (LSTM)               (None, 32)                12416
# _________________________________________________________________
# dense_25 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dense_26 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 282,561
# Trainable params: 282,561
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 13761 samples, validate on 1529 samples
# Epoch 1/100
# 13761/13761 [==============================] - 10s 752us/step - loss: 0.6722 - acc: 0.5617 - val_loss: 0.6388 - val_acc: 0.5716
# Epoch 2/100
# 13761/13761 [==============================] - 3s 210us/step - loss: 0.6552 - acc: 0.6207 - val_loss: 0.6468 - val_acc: 0.4794
# Epoch 3/100
# 13761/13761 [==============================] - 3s 208us/step - loss: 0.6484 - acc: 0.6122 - val_loss: 0.6370 - val_acc: 0.5893
# Epoch 4/100
# 13761/13761 [==============================] - 3s 208us/step - loss: 0.6371 - acc: 0.6224 - val_loss: 0.6355 - val_acc: 0.6050
# Epoch 5/100
# 13761/13761 [==============================] - 3s 206us/step - loss: 0.6332 - acc: 0.6127 - val_loss: 0.6595 - val_acc: 0.6789
# Epoch 6/100
# 13761/13761 [==============================] - 3s 208us/step - loss: 0.6113 - acc: 0.6215 - val_loss: 0.6582 - val_acc: 0.6527
# Epoch 7/100
# 13761/13761 [==============================] - 3s 211us/step - loss: 0.5956 - acc: 0.6329 - val_loss: 0.6812 - val_acc: 0.6789
# Epoch 8/100
# 13761/13761 [==============================] - 3s 211us/step - loss: 0.5650 - acc: 0.6604 - val_loss: 0.6697 - val_acc: 0.5860
# Epoch 9/100
# 13761/13761 [==============================] - 3s 210us/step - loss: 0.5454 - acc: 0.6653 - val_loss: 0.7514 - val_acc: 0.6638
# Epoch 10/100
# 13761/13761 [==============================] - 3s 210us/step - loss: 0.5283 - acc: 0.6815 - val_loss: 0.7549 - val_acc: 0.6494
# Epoch 00010: early stopping
# [[2767 1586]
#  [ 217  262]]
# accuracy  : 0.6268625827814569
# f1 score  : 0.2251826385904598
# precision : 0.14177489177489178
# recall    : 0.5469728601252609
# WA        : 59.13132161871423
#               precision    recall  f1-score   support
#
#            0       0.93      0.64      0.75      4353
#            1       0.14      0.55      0.23       479
#
#     accuracy                           0.63      4832
#    macro avg       0.53      0.59      0.49      4832
# weighted avg       0.85      0.63      0.70      4832

# %%
files.download("text_happy.h5")
files.download("text_angry.h5")
files.download("text_sad.h5")
files.download("text_fear.h5")
files.download("text_surprise.h5")
files.download("text_disgust.h5")
