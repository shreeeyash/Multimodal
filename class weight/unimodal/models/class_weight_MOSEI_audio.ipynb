# %%
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/data/audio_test.h5"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/data/audio_train.h5"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/data/text_test_emb.h5"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/data/text_train_emb.h5"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/data/video_test.h5"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/data/video_train.h5"

# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Test_labels_2class.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Test_labels_5class.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Test_labels_7class.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Test_labels_angry.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Test_labels_disgust.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Test_labels_fear.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Test_labels_happy.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Test_labels_sad.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Test_labels_surprise.csv"

# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Train_labels_2class.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Train_labels_5class.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Train_labels_7class.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Train_labels_angry.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Train_labels_disgust.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Train_labels_fear.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Train_labels_happy.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Train_labels_sad.csv"
# !wget "http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Train_labels_surprise.csv"
# Out:
# --2019-07-26 09:01:17--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/data/audio_test.h5
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 57213024 (55M)
# Saving to: ‘audio_test.h5.1’
#
# audio_test.h5.1     100%[===================>]  54.56M  10.6MB/s    in 5.7s
#
# 2019-07-26 09:01:23 (9.60 MB/s) - ‘audio_test.h5.1’ saved [57213024/57213024]
#
# --2019-07-26 09:01:25--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/data/audio_train.h5
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 181035744 (173M)
# Saving to: ‘audio_train.h5.1’
#
# audio_train.h5.1    100%[===================>] 172.65M  11.0MB/s    in 16s
#
# 2019-07-26 09:01:41 (10.6 MB/s) - ‘audio_train.h5.1’ saved [181035744/181035744]
#
# --2019-07-26 09:01:43--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/data/text_test_emb.h5
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 231938144 (221M)
# Saving to: ‘text_test_emb.h5.1’
#
# text_test_emb.h5.1  100%[===================>] 221.19M  10.7MB/s    in 21s
#
# 2019-07-26 09:02:04 (10.4 MB/s) - ‘text_test_emb.h5.1’ saved [231938144/231938144]
#
# --2019-07-26 09:02:06--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/data/text_train_emb.h5
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 733922144 (700M)
# Saving to: ‘text_train_emb.h5.1’
#
# text_train_emb.h5.1 100%[===================>] 699.92M  10.8MB/s    in 66s
#
# 2019-07-26 09:03:12 (10.6 MB/s) - ‘text_train_emb.h5.1’ saved [733922144/733922144]
#
# --2019-07-26 09:03:14--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/data/video_test.h5
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 27061344 (26M)
# Saving to: ‘video_test.h5.1’
#
# video_test.h5.1     100%[===================>]  25.81M  8.67MB/s    in 3.0s
#
# 2019-07-26 09:03:17 (8.67 MB/s) - ‘video_test.h5.1’ saved [27061344/27061344]
#
# --2019-07-26 09:03:19--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/data/video_train.h5
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 85626144 (82M)
# Saving to: ‘video_train.h5.1’
#
# video_train.h5.1    100%[===================>]  81.66M  11.0MB/s    in 8.1s
#
# 2019-07-26 09:03:28 (10.1 MB/s) - ‘video_train.h5.1’ saved [85626144/85626144]
#
# --2019-07-26 09:03:29--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Test_labels_2class.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9664 (9.4K) [text/csv]
# Saving to: ‘mosi2uni_Test_labels_2class.csv.1’
#
# mosi2uni_Test_label 100%[===================>]   9.44K  --.-KB/s    in 0s
#
# 2019-07-26 09:03:29 (34.6 MB/s) - ‘mosi2uni_Test_labels_2class.csv.1’ saved [9664/9664]
#
# --2019-07-26 09:03:32--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Test_labels_5class.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9664 (9.4K) [text/csv]
# Saving to: ‘mosi2uni_Test_labels_5class.csv.1’
#
# mosi2uni_Test_label 100%[===================>]   9.44K  --.-KB/s    in 0s
#
# 2019-07-26 09:03:33 (30.4 MB/s) - ‘mosi2uni_Test_labels_5class.csv.1’ saved [9664/9664]
#
# --2019-07-26 09:03:35--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Test_labels_7class.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9664 (9.4K) [text/csv]
# Saving to: ‘mosi2uni_Test_labels_7class.csv.1’
#
# mosi2uni_Test_label 100%[===================>]   9.44K  --.-KB/s    in 0.001s
#
# 2019-07-26 09:03:36 (18.2 MB/s) - ‘mosi2uni_Test_labels_7class.csv.1’ saved [9664/9664]
#
# --2019-07-26 09:03:39--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Test_labels_angry.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9664 (9.4K) [text/csv]
# Saving to: ‘mosi2uni_Test_labels_angry.csv.1’
#
# mosi2uni_Test_label 100%[===================>]   9.44K  --.-KB/s    in 0s
#
# 2019-07-26 09:03:39 (104 MB/s) - ‘mosi2uni_Test_labels_angry.csv.1’ saved [9664/9664]
#
# --2019-07-26 09:03:41--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Test_labels_disgust.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9664 (9.4K) [text/csv]
# Saving to: ‘mosi2uni_Test_labels_disgust.csv.1’
#
# mosi2uni_Test_label 100%[===================>]   9.44K  --.-KB/s    in 0s
#
# 2019-07-26 09:03:42 (33.4 MB/s) - ‘mosi2uni_Test_labels_disgust.csv.1’ saved [9664/9664]
#
# --2019-07-26 09:03:44--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Test_labels_fear.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9664 (9.4K) [text/csv]
# Saving to: ‘mosi2uni_Test_labels_fear.csv.1’
#
# mosi2uni_Test_label 100%[===================>]   9.44K  --.-KB/s    in 0s
#
# 2019-07-26 09:03:44 (39.5 MB/s) - ‘mosi2uni_Test_labels_fear.csv.1’ saved [9664/9664]
#
# --2019-07-26 09:03:48--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Test_labels_happy.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9664 (9.4K) [text/csv]
# Saving to: ‘mosi2uni_Test_labels_happy.csv.1’
#
# mosi2uni_Test_label 100%[===================>]   9.44K  --.-KB/s    in 0s
#
# 2019-07-26 09:03:48 (78.6 MB/s) - ‘mosi2uni_Test_labels_happy.csv.1’ saved [9664/9664]
#
# --2019-07-26 09:03:51--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Test_labels_sad.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9664 (9.4K) [text/csv]
# Saving to: ‘mosi2uni_Test_labels_sad.csv.1’
#
# mosi2uni_Test_label 100%[===================>]   9.44K  --.-KB/s    in 0s
#
# 2019-07-26 09:03:51 (36.4 MB/s) - ‘mosi2uni_Test_labels_sad.csv.1’ saved [9664/9664]
#
# --2019-07-26 09:03:54--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Test_labels_surprise.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9664 (9.4K) [text/csv]
# Saving to: ‘mosi2uni_Test_labels_surprise.csv.1’
#
# mosi2uni_Test_label 100%[===================>]   9.44K  --.-KB/s    in 0s
#
# 2019-07-26 09:03:54 (34.6 MB/s) - ‘mosi2uni_Test_labels_surprise.csv.1’ saved [9664/9664]
#
# --2019-07-26 09:03:57--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Train_labels_2class.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 30580 (30K) [text/csv]
# Saving to: ‘mosi2uni_Train_labels_2class.csv.1’
#
# mosi2uni_Train_labe 100%[===================>]  29.86K  --.-KB/s    in 0.1s
#
# 2019-07-26 09:03:57 (304 KB/s) - ‘mosi2uni_Train_labels_2class.csv.1’ saved [30580/30580]
#
# --2019-07-26 09:04:00--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Train_labels_5class.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 30580 (30K) [text/csv]
# Saving to: ‘mosi2uni_Train_labels_5class.csv.1’
#
# mosi2uni_Train_labe 100%[===================>]  29.86K  --.-KB/s    in 0.1s
#
# 2019-07-26 09:04:00 (304 KB/s) - ‘mosi2uni_Train_labels_5class.csv.1’ saved [30580/30580]
#
# --2019-07-26 09:04:03--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Train_labels_7class.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 30580 (30K) [text/csv]
# Saving to: ‘mosi2uni_Train_labels_7class.csv.1’
#
# mosi2uni_Train_labe 100%[===================>]  29.86K  --.-KB/s    in 0.1s
#
# 2019-07-26 09:04:04 (305 KB/s) - ‘mosi2uni_Train_labels_7class.csv.1’ saved [30580/30580]
#
# --2019-07-26 09:04:06--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Train_labels_angry.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 30580 (30K) [text/csv]
# Saving to: ‘mosi2uni_Train_labels_angry.csv.1’
#
# mosi2uni_Train_labe 100%[===================>]  29.86K  --.-KB/s    in 0.1s
#
# 2019-07-26 09:04:07 (304 KB/s) - ‘mosi2uni_Train_labels_angry.csv.1’ saved [30580/30580]
#
# --2019-07-26 09:04:10--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Train_labels_disgust.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 30580 (30K) [text/csv]
# Saving to: ‘mosi2uni_Train_labels_disgust.csv.1’
#
# mosi2uni_Train_labe 100%[===================>]  29.86K  --.-KB/s    in 0.1s
#
# 2019-07-26 09:04:10 (304 KB/s) - ‘mosi2uni_Train_labels_disgust.csv.1’ saved [30580/30580]
#
# --2019-07-26 09:04:13--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Train_labels_fear.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 30580 (30K) [text/csv]
# Saving to: ‘mosi2uni_Train_labels_fear.csv.1’
#
# mosi2uni_Train_labe 100%[===================>]  29.86K  --.-KB/s    in 0.1s
#
# 2019-07-26 09:04:14 (306 KB/s) - ‘mosi2uni_Train_labels_fear.csv.1’ saved [30580/30580]
#
# --2019-07-26 09:04:16--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Train_labels_happy.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 30580 (30K) [text/csv]
# Saving to: ‘mosi2uni_Train_labels_happy.csv.1’
#
# mosi2uni_Train_labe 100%[===================>]  29.86K  --.-KB/s    in 0.1s
#
# 2019-07-26 09:04:17 (304 KB/s) - ‘mosi2uni_Train_labels_happy.csv.1’ saved [30580/30580]
#
# --2019-07-26 09:04:19--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Train_labels_sad.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 30580 (30K) [text/csv]
# Saving to: ‘mosi2uni_Train_labels_sad.csv.1’
#
# mosi2uni_Train_labe 100%[===================>]  29.86K  --.-KB/s    in 0.1s
#
# 2019-07-26 09:04:19 (304 KB/s) - ‘mosi2uni_Train_labels_sad.csv.1’ saved [30580/30580]
#
# --2019-07-26 09:04:24--  http://immortal.multicomp.cs.cmu.edu/raw_datasets/old_processed_data/cmu-mosei/labels/mosi2uni_Train_labels_surprise.csv
# Resolving immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)... 128.2.211.216
# Connecting to immortal.multicomp.cs.cmu.edu (immortal.multicomp.cs.cmu.edu)|128.2.211.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 30580 (30K) [text/csv]
# Saving to: ‘mosi2uni_Train_labels_surprise.csv.1’
#
# mosi2uni_Train_labe 100%[===================>]  29.86K  --.-KB/s    in 0.1s
#
# 2019-07-26 09:04:24 (304 KB/s) - ‘mosi2uni_Train_labels_surprise.csv.1’ saved [30580/30580]

# %%
import pandas as pd
import numpy as np
import h5py
from sklearn.metrics import classification_report
from keras.models import load_model
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import *
from sklearn.utils.multiclass import unique_labels
import keras
import tensorflow as tf
from time import time
import scipy
from keras import layers
from google.colab import files	
from sklearn.utils import class_weight
from keras.models import load_model
from keras.models import Model,Sequential,Model
from keras.layers import *
from keras.callbacks import TensorBoard
from keras import callbacks
from keras.callbacks import *
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
import pandas as pd
import numpy as np
import h5py

Test_labels_fear = np.array(pd.read_csv("mosi2uni_Test_labels_fear.csv",header=None))
Train_labels_fear = np.array(pd.read_csv("mosi2uni_Train_labels_fear.csv",header=None))

Test_labels_happy = np.array(pd.read_csv("mosi2uni_Test_labels_happy.csv",header=None))
Train_labels_happy = np.array(pd.read_csv("mosi2uni_Train_labels_happy.csv",header=None))

Test_labels_sad = np.array(pd.read_csv("mosi2uni_Test_labels_sad.csv",header=None))
Train_labels_sad = np.array(pd.read_csv("mosi2uni_Train_labels_sad.csv",header=None))

Test_labels_disgust = np.array(pd.read_csv("mosi2uni_Test_labels_disgust.csv",header=None))
Train_labels_disgust = np.array(pd.read_csv("mosi2uni_Train_labels_disgust.csv",header=None))

Test_labels_surprise = np.array(pd.read_csv("mosi2uni_Test_labels_surprise.csv",header=None))
Train_labels_surprise = np.array(pd.read_csv("mosi2uni_Train_labels_surprise.csv",header=None))

Test_labels_angry = np.array(pd.read_csv("mosi2uni_Test_labels_angry.csv",header=None))
Train_labels_angry = np.array(pd.read_csv("mosi2uni_Train_labels_angry.csv",header=None))

X_train = h5py.File("audio_train.h5","r")
X_train = np.array(X_train.get('d1'))

X_test = h5py.File("audio_test.h5","r")
X_test = np.array(X_test.get('d1'))
print(X_train.shape,X_test.shape)
# Out:
# (15290, 20, 74) (4832, 20, 74)

# %%
flat_train = X_train.reshape((15290,20*74))
flat_test = X_test.reshape((4832,20*74))

# %%
from sklearn.utils import class_weight
class_weight = class_weight.compute_class_weight('balanced',np.unique(Train_labels_surprise.squeeze()),Train_labels_surprise.squeeze())
print(class_weight)
# Out:
# [0.55689103 4.8943662 ]

# %%
from sklearn.utils import class_weight
class_weight = class_weight.compute_class_weight('balanced',np.unique(Train_labels_happy.squeeze()),Train_labels_happy.squeeze())
print(class_weight)

i = Input(shape=(20,74))
x = LSTM(64,return_sequences = True)(i)
x = LSTM(32,return_sequences = True)(x)
x = LSTM(32,return_sequences = False)(x)
x = Dense(32,activation='relu')(x)
x = Dense(1,activation='sigmoid')(x)

model = Model(i,x)
print(model.summary())
model.compile('adam','binary_crossentropy',metrics=['accuracy'])

es = EarlyStopping(monitor='val_acc',mode='max' ,patience=5, min_delta=0.0001,verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_acc', factor=0.2,patience=2,min_lr=0.00001)
model.fit(X_train,Train_labels_happy,512,epochs=100,validation_split=0.1,callbacks=[es,reduce_lr],
          class_weight=dict(enumerate(class_weight)))


y_pred = (model.predict(X_test)>0.5).astype("float")
y_true = Test_labels_happy
cm = confusion_matrix(y_true,y_pred)

p = precision_score(y_true,y_pred)
a = accuracy_score(y_true,y_pred)
r = recall_score(y_true,y_pred)
f = f1_score(y_true,y_pred)
print(cm)
print("accuracy  :",a)
print("f1 score  :",f)
print("precision :",p)
print("recall    :",r)


TP = cm[1][1]
TN = cm[0][0]
P = Test_labels_happy.sum()
N = 4832-P
wa = ((TP*N/P) + TN)/(0.02*N)
print("WA        :",wa)
print(classification_report(y_true,y_pred))
model.save("audio_happy.h5")
# Out:
# [1.07027859 0.93838223]
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 20, 74)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 20, 64)            35584
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 20, 32)            12416
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 32)                8320
# _________________________________________________________________
# dense_4 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 57,409
# Trainable params: 57,409
# Non-trainable params: 0
# _________________________________________________________________
# None
# W0726 09:10:03.385255 139725343913856 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
# Train on 13761 samples, validate on 1529 samples
# Epoch 1/100
# 13761/13761 [==============================] - 9s 663us/step - loss: 0.6814 - acc: 0.5989 - val_loss: 0.6756 - val_acc: 0.5912
# Epoch 2/100
# 13761/13761 [==============================] - 6s 415us/step - loss: 0.6666 - acc: 0.6066 - val_loss: 0.6804 - val_acc: 0.5533
# Epoch 3/100
# 13761/13761 [==============================] - 6s 407us/step - loss: 0.6628 - acc: 0.6101 - val_loss: 0.6778 - val_acc: 0.6010
# Epoch 4/100
# 13761/13761 [==============================] - 5s 390us/step - loss: 0.6595 - acc: 0.6159 - val_loss: 0.6843 - val_acc: 0.5284
# Epoch 5/100
# 13761/13761 [==============================] - 5s 390us/step - loss: 0.6599 - acc: 0.6151 - val_loss: 0.6758 - val_acc: 0.5912
# Epoch 6/100
# 13761/13761 [==============================] - 5s 391us/step - loss: 0.6562 - acc: 0.6204 - val_loss: 0.6777 - val_acc: 0.5775
# Epoch 7/100
# 13761/13761 [==============================] - 7s 502us/step - loss: 0.6555 - acc: 0.6210 - val_loss: 0.6792 - val_acc: 0.5834
# Epoch 8/100
# 13761/13761 [==============================] - 6s 438us/step - loss: 0.6548 - acc: 0.6208 - val_loss: 0.6792 - val_acc: 0.5840
# Epoch 00008: early stopping
# [[1509  801]
#  [1005 1517]]
# accuracy  : 0.6262417218543046
# f1 score  : 0.6268595041322313
# precision : 0.6544434857635893
# recall    : 0.6015067406819984
# WA        : 62.73767469643758
#               precision    recall  f1-score   support
#
#            0       0.60      0.65      0.63      2310
#            1       0.65      0.60      0.63      2522
#
#     accuracy                           0.63      4832
#    macro avg       0.63      0.63      0.63      4832
# weighted avg       0.63      0.63      0.63      4832

# %%
from sklearn.utils import class_weight
class_weight = class_weight.compute_class_weight('balanced',np.unique(Train_labels_fear.squeeze()),Train_labels_fear.squeeze())
print(class_weight)

i = Input(shape=(20,74))
x = LSTM(64,return_sequences = True)(i)
x = LSTM(32,return_sequences = True)(x)
x = LSTM(32,return_sequences = False)(x)
x = Dense(32,activation='relu')(x)
x = Dense(1,activation='sigmoid')(x)

model = Model(i,x)
print(model.summary())
model.compile('adam','binary_crossentropy',metrics=['accuracy'])

es = EarlyStopping(monitor='val_acc',mode='max' ,patience=5, min_delta=0.0001,verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_acc', factor=0.2,patience=2,min_lr=0.00001)
model.fit(X_train,Train_labels_fear,512,epochs=100,validation_split=0.1,callbacks=[es,reduce_lr],
          class_weight=dict(enumerate(class_weight)))


y_pred = (model.predict(X_test)>0.5).astype("float")
y_true = Test_labels_fear
cm = confusion_matrix(y_true,y_pred)

p = precision_score(y_true,y_pred)
a = accuracy_score(y_true,y_pred)
r = recall_score(y_true,y_pred)
f = f1_score(y_true,y_pred)
print(cm)
print("accuracy  :",a)
print("f1 score  :",f)
print("precision :",p)
print("recall    :",r)


TP = cm[1][1]
TN = cm[0][0]
P = Test_labels_fear.sum()
N = 4832-P
wa = ((TP*N/P) + TN)/(0.02*N)
print("WA        :",wa)
print(classification_report(y_true,y_pred))
model.save("audio_fear.h5")
# Out:
# [0.54720492 5.79605762]
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 20, 74)            0
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 20, 64)            35584
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 20, 32)            12416
# _________________________________________________________________
# lstm_6 (LSTM)                (None, 32)                8320
# _________________________________________________________________
# dense_6 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 57,409
# Trainable params: 57,409
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 13761 samples, validate on 1529 samples
# Epoch 1/100
# 13761/13761 [==============================] - 11s 812us/step - loss: 0.6819 - acc: 0.3674 - val_loss: 0.6943 - val_acc: 0.3649
# Epoch 2/100
# 13761/13761 [==============================] - 7s 531us/step - loss: 0.6546 - acc: 0.5180 - val_loss: 0.6911 - val_acc: 0.5350
# Epoch 3/100
# 13761/13761 [==============================] - 7s 474us/step - loss: 0.6471 - acc: 0.5840 - val_loss: 0.7120 - val_acc: 0.5755
# Epoch 4/100
# 13761/13761 [==============================] - 5s 371us/step - loss: 0.6436 - acc: 0.6097 - val_loss: 0.7127 - val_acc: 0.5592
# Epoch 5/100
# 13761/13761 [==============================] - 6s 467us/step - loss: 0.6395 - acc: 0.5914 - val_loss: 0.7012 - val_acc: 0.6475
# Epoch 6/100
# 13761/13761 [==============================] - 7s 487us/step - loss: 0.6373 - acc: 0.6242 - val_loss: 0.7112 - val_acc: 0.6259
# Epoch 7/100
# 13761/13761 [==============================] - 6s 421us/step - loss: 0.6355 - acc: 0.6425 - val_loss: 0.7176 - val_acc: 0.5572
# Epoch 8/100
# 13761/13761 [==============================] - 5s 354us/step - loss: 0.6328 - acc: 0.6244 - val_loss: 0.7103 - val_acc: 0.5925
# Epoch 9/100
# 13761/13761 [==============================] - 5s 361us/step - loss: 0.6308 - acc: 0.6359 - val_loss: 0.7086 - val_acc: 0.6056
# Epoch 10/100
# 13761/13761 [==============================] - 5s 347us/step - loss: 0.6294 - acc: 0.6386 - val_loss: 0.7080 - val_acc: 0.6076
# Epoch 00010: early stopping
# [[2974 1526]
#  [ 127  205]]
# accuracy  : 0.6579056291390728
# f1 score  : 0.19873969946679593
# precision : 0.11842865395725015
# recall    : 0.6174698795180723
# WA        : 63.91793842034806
#               precision    recall  f1-score   support
#
#            0       0.96      0.66      0.78      4500
#            1       0.12      0.62      0.20       332
#
#     accuracy                           0.66      4832
#    macro avg       0.54      0.64      0.49      4832
# weighted avg       0.90      0.66      0.74      4832

# %%
from sklearn.utils import class_weight
class_weight = class_weight.compute_class_weight('balanced',np.unique(Train_labels_angry.squeeze()),Train_labels_angry.squeeze())
print(class_weight)

i = Input(shape=(20,74))
x = LSTM(64,return_sequences = True)(i)
x = LSTM(32,return_sequences = True)(x)
x = LSTM(32,return_sequences = False)(x)
x = Dense(32,activation='relu')(x)
x = Dense(1,activation='sigmoid')(x)

model = Model(i,x)
print(model.summary())
model.compile('adam','binary_crossentropy',metrics=['accuracy'])

es = EarlyStopping(monitor='val_acc',mode='max' ,patience=5, min_delta=0.0001,verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_acc', factor=0.2,patience=2,min_lr=0.00001)
model.fit(X_train,Train_labels_angry,512,epochs=100,validation_split=0.1,callbacks=[es,reduce_lr],
          class_weight=dict(enumerate(class_weight)))


y_pred = (model.predict(X_test)>0.5).astype("float")
y_true = Test_labels_angry
cm = confusion_matrix(y_true,y_pred)

p = precision_score(y_true,y_pred)
a = accuracy_score(y_true,y_pred)
r = recall_score(y_true,y_pred)
f = f1_score(y_true,y_pred)
print(cm)
print("accuracy  :",a)
print("f1 score  :",f)
print("precision :",p)
print("recall    :",r)


TP = cm[1][1]
TN = cm[0][0]
P = Test_labels_angry.sum()
N = 4832-P
wa = ((TP*N/P) + TN)/(0.02*N)
print("WA        :",wa)
print(classification_report(y_true,y_pred))
model.save("audio_angry.h5")
# Out:
# [0.64531105 2.22044728]
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         (None, 20, 74)            0
# _________________________________________________________________
# lstm_7 (LSTM)                (None, 20, 64)            35584
# _________________________________________________________________
# lstm_8 (LSTM)                (None, 20, 32)            12416
# _________________________________________________________________
# lstm_9 (LSTM)                (None, 32)                8320
# _________________________________________________________________
# dense_8 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 57,409
# Trainable params: 57,409
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 13761 samples, validate on 1529 samples
# Epoch 1/100
# 13761/13761 [==============================] - 9s 683us/step - loss: 0.6822 - acc: 0.6789 - val_loss: 0.6480 - val_acc: 0.6579
# Epoch 2/100
# 13761/13761 [==============================] - 6s 427us/step - loss: 0.6681 - acc: 0.6750 - val_loss: 0.6382 - val_acc: 0.6723
# Epoch 3/100
# 13761/13761 [==============================] - 7s 501us/step - loss: 0.6665 - acc: 0.6768 - val_loss: 0.6333 - val_acc: 0.6717
# Epoch 4/100
# 13761/13761 [==============================] - 5s 353us/step - loss: 0.6635 - acc: 0.6683 - val_loss: 0.6328 - val_acc: 0.6723
# Epoch 5/100
# 13761/13761 [==============================] - 7s 533us/step - loss: 0.6623 - acc: 0.6500 - val_loss: 0.6299 - val_acc: 0.6723
# Epoch 6/100
# 13761/13761 [==============================] - 7s 530us/step - loss: 0.6606 - acc: 0.6486 - val_loss: 0.6271 - val_acc: 0.6645
# Epoch 7/100
# 13761/13761 [==============================] - 7s 539us/step - loss: 0.6595 - acc: 0.6522 - val_loss: 0.6271 - val_acc: 0.6586
# Epoch 00007: early stopping
# [[2436 1425]
#  [ 390  581]]
# accuracy  : 0.6243791390728477
# f1 score  : 0.39032583137386634
# precision : 0.2896311066799601
# recall    : 0.5983522142121525
# WA        : 61.463842256839165
#               precision    recall  f1-score   support
#
#            0       0.86      0.63      0.73      3861
#            1       0.29      0.60      0.39       971
#
#     accuracy                           0.62      4832
#    macro avg       0.58      0.61      0.56      4832
# weighted avg       0.75      0.62      0.66      4832

# %%
m = Sequential()
model = load_model("happy.h5")
for layer in model.layers[:-1]:
  layer.trainable = False
  m.add(layer)
print(m.summary())
Dtrain_happy = m.predict(X_train)
Dtest_happy = m.predict(X_test)
print(Dtrain_happy.shape,Dtest_happy.shape)
scipy.io.savemat("Dtrain_happy.mat",{'val':Dtrain_happy})
scipy.io.savemat("Dtest_happy.mat",{'val':Dtest_happy})
files.download("Dtrain_happy.mat")
files.download("Dtest_happy.mat")
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_40 (LSTM)               (None, 20, 64)            35584
# _________________________________________________________________
# lstm_41 (LSTM)               (None, 20, 32)            12416
# _________________________________________________________________
# lstm_42 (LSTM)               (None, 32)                8320
# _________________________________________________________________
# dense_111 (Dense)            (None, 32)                1056
# =================================================================
# Total params: 57,376
# Trainable params: 0
# Non-trainable params: 57,376
# _________________________________________________________________
# None
# (15290, 32) (4832, 32)

# %%
m = Sequential()
model = load_model("fear.h5")
for layer in model.layers[:-1]:
  layer.trainable = False
  m.add(layer)
print(m.summary())
Dtrain_fear = m.predict(X_train)
Dtest_fear = m.predict(X_test)
print(Dtrain_fear.shape,Dtest_fear.shape)
scipy.io.savemat("Dtrain_fear.mat",{'val':Dtrain_fear})
scipy.io.savemat("Dtest_fear.mat",{'val':Dtest_fear})
files.download("Dtrain_fear.mat")
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_43 (LSTM)               (None, 20, 64)            35584
# _________________________________________________________________
# lstm_44 (LSTM)               (None, 20, 32)            12416
# _________________________________________________________________
# lstm_45 (LSTM)               (None, 32)                8320
# _________________________________________________________________
# dense_113 (Dense)            (None, 32)                1056
# =================================================================
# Total params: 57,376
# Trainable params: 0
# Non-trainable params: 57,376
# _________________________________________________________________
# None
# (15290, 32) (4832, 32)

# %%
m = Sequential()
model = load_model("angry.h5")
for layer in model.layers[:-2]:
  layer.trainable = False
  m.add(layer)
print(m.summary())
Dtrain_angry = m.predict(X_train)
Dtest_angry = m.predict(X_test)
print(Dtrain_angry.shape,Dtest_angry.shape)
scipy.io.savemat("Dtrain_angry.mat",{'val':Dtrain_angry})
scipy.io.savemat("Dtest_angry.mat",{'val':Dtest_angry})
files.download("Dtrain_angry.mat")
files.download("Dtest_angry.mat")
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 20, 64)            35584
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 20, 32)            12416
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 32)                8320
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                1056
# =================================================================
# Total params: 57,376
# Trainable params: 0
# Non-trainable params: 57,376
# _________________________________________________________________
# None
# (15290, 32) (4832, 32)

# %%
files.download("Dtest_fear.mat")

# %%
from sklearn.utils import class_weight
class_weight = class_weight.compute_class_weight('balanced',np.unique(Train_labels_sad.squeeze()),Train_labels_sad.squeeze())
print(class_weight)

i = Input(shape=(20,74))
x = LSTM(64,return_sequences = True)(i)
x = LSTM(32,return_sequences = True)(x)
x = LSTM(32,return_sequences = False)(x)
x = Dense(32,activation='relu')(x)
x = Dense(1,activation='sigmoid')(x)

model = Model(i,x)
print(model.summary())
model.compile('adam','binary_crossentropy',metrics=['accuracy'])

es = EarlyStopping(monitor='val_acc',mode='max' ,patience=5, min_delta=0.0001,verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_acc', factor=0.2,patience=2,min_lr=0.00001)
model.fit(X_train,Train_labels_sad,512,epochs=100,validation_split=0.1,callbacks=[es,reduce_lr],
          class_weight=dict(enumerate(class_weight)))


y_pred = (model.predict(X_test)>0.5).astype("float")
y_true = Test_labels_sad
cm = confusion_matrix(y_true,y_pred)

p = precision_score(y_true,y_pred)
a = accuracy_score(y_true,y_pred)
r = recall_score(y_true,y_pred)
f = f1_score(y_true,y_pred)
print(cm)
print("accuracy  :",a)
print("f1 score  :",f)
print("precision :",p)
print("recall    :",r)


TP = cm[1][1]
TN = cm[0][0]
P = Test_labels_sad.sum()
N = 4832-P
wa = ((TP*N/P) + TN)/(0.02*N)
print("WA        :",wa)
print(classification_report(y_true,y_pred))
model.save("audio_sad.h5")
# Out:
# [0.67155657 1.95724526]
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         (None, 20, 74)            0
# _________________________________________________________________
# lstm_10 (LSTM)               (None, 20, 64)            35584
# _________________________________________________________________
# lstm_11 (LSTM)               (None, 20, 32)            12416
# _________________________________________________________________
# lstm_12 (LSTM)               (None, 32)                8320
# _________________________________________________________________
# dense_10 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 57,409
# Trainable params: 57,409
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 13761 samples, validate on 1529 samples
# Epoch 1/100
# 13761/13761 [==============================] - 13s 968us/step - loss: 0.6894 - acc: 0.6518 - val_loss: 0.6672 - val_acc: 0.5173
# Epoch 2/100
# 13761/13761 [==============================] - 7s 478us/step - loss: 0.6824 - acc: 0.5594 - val_loss: 0.6574 - val_acc: 0.6272
# Epoch 3/100
# 13761/13761 [==============================] - 5s 350us/step - loss: 0.6784 - acc: 0.5990 - val_loss: 0.6559 - val_acc: 0.6364
# Epoch 4/100
# 13761/13761 [==============================] - 6s 451us/step - loss: 0.6752 - acc: 0.5900 - val_loss: 0.6560 - val_acc: 0.5592
# Epoch 5/100
# 13761/13761 [==============================] - 7s 475us/step - loss: 0.6751 - acc: 0.5714 - val_loss: 0.6657 - val_acc: 0.5016
# Epoch 6/100
# 13761/13761 [==============================] - 5s 390us/step - loss: 0.6743 - acc: 0.5793 - val_loss: 0.6531 - val_acc: 0.6109
# Epoch 7/100
# 13761/13761 [==============================] - 5s 393us/step - loss: 0.6720 - acc: 0.5881 - val_loss: 0.6537 - val_acc: 0.5788
# Epoch 8/100
# 13761/13761 [==============================] - 5s 392us/step - loss: 0.6710 - acc: 0.5837 - val_loss: 0.6524 - val_acc: 0.5880
# Epoch 00008: early stopping
# [[2024 1474]
#  [ 493  841]]
# accuracy  : 0.5929221854304636
# f1 score  : 0.46094820498766786
# precision : 0.36328293736501077
# recall    : 0.6304347826086957
# WA        : 60.45255674049768
#               precision    recall  f1-score   support
#
#            0       0.80      0.58      0.67      3498
#            1       0.36      0.63      0.46      1334
#
#     accuracy                           0.59      4832
#    macro avg       0.58      0.60      0.57      4832
# weighted avg       0.68      0.59      0.61      4832

# %%
from sklearn.utils import class_weight
class_weight = class_weight.compute_class_weight('balanced',np.unique(Train_labels_disgust.squeeze()),Train_labels_disgust.squeeze())
print(class_weight)

i = Input(shape=(20,74))
x = LSTM(64,return_sequences = True)(i)
x = LSTM(32,return_sequences = True)(x)
x = LSTM(32,return_sequences = False)(x)
x = Dense(32,activation='relu')(x)
x = Dense(1,activation='sigmoid')(x)

model = Model(i,x)
print(model.summary())
model.compile('adam','binary_crossentropy',metrics=['accuracy'])

es = EarlyStopping(monitor='val_acc',mode='max' ,patience=5, min_delta=0.0001,verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_acc', factor=0.2,patience=2,min_lr=0.00001)
model.fit(X_train,Train_labels_disgust,512,epochs=100,validation_split=0.1,callbacks=[es,reduce_lr],
          class_weight=dict(enumerate(class_weight)))


y_pred = (model.predict(X_test)>0.5).astype("float")
y_true = Test_labels_disgust
cm = confusion_matrix(y_true,y_pred)

p = precision_score(y_true,y_pred)
a = accuracy_score(y_true,y_pred)
r = recall_score(y_true,y_pred)
f = f1_score(y_true,y_pred)
print(cm)
print("accuracy  :",a)
print("f1 score  :",f)
print("precision :",p)
print("recall    :",r)


TP = cm[1][1]
TN = cm[0][0]
P = Test_labels_disgust.sum()
N = 4832-P
wa = ((TP*N/P) + TN)/(0.02*N)
print("WA        :",wa)
print(classification_report(y_true,y_pred))
model.save("audio_disgust.h5")
# Out:
# [0.60819411 2.81066176]
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         (None, 20, 74)            0
# _________________________________________________________________
# lstm_13 (LSTM)               (None, 20, 64)            35584
# _________________________________________________________________
# lstm_14 (LSTM)               (None, 20, 32)            12416
# _________________________________________________________________
# lstm_15 (LSTM)               (None, 32)                8320
# _________________________________________________________________
# dense_12 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 57,409
# Trainable params: 57,409
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 13761 samples, validate on 1529 samples
# Epoch 1/100
# 13761/13761 [==============================] - 11s 831us/step - loss: 0.6648 - acc: 0.7610 - val_loss: 0.5906 - val_acc: 0.7659
# Epoch 2/100
# 13761/13761 [==============================] - 6s 471us/step - loss: 0.6228 - acc: 0.7253 - val_loss: 0.5689 - val_acc: 0.7587
# Epoch 3/100
# 13761/13761 [==============================] - 6s 432us/step - loss: 0.6175 - acc: 0.7290 - val_loss: 0.5742 - val_acc: 0.7600
# Epoch 4/100
# 13761/13761 [==============================] - 7s 519us/step - loss: 0.6142 - acc: 0.7285 - val_loss: 0.5682 - val_acc: 0.7626
# Epoch 5/100
# 13761/13761 [==============================] - 7s 539us/step - loss: 0.6133 - acc: 0.7312 - val_loss: 0.5674 - val_acc: 0.7626
# Epoch 6/100
# 13761/13761 [==============================] - 6s 411us/step - loss: 0.6131 - acc: 0.7313 - val_loss: 0.5677 - val_acc: 0.7626
# Epoch 00006: early stopping
# [[2863 1047]
#  [ 283  639]]
# accuracy  : 0.7247516556291391
# f1 score  : 0.49003067484662577
# precision : 0.3790035587188612
# recall    : 0.693058568329718
# WA        : 71.26418161341685
#               precision    recall  f1-score   support
#
#            0       0.91      0.73      0.81      3910
#            1       0.38      0.69      0.49       922
#
#     accuracy                           0.72      4832
#    macro avg       0.64      0.71      0.65      4832
# weighted avg       0.81      0.72      0.75      4832

# %%
from sklearn.utils import class_weight
class_weight = class_weight.compute_class_weight('balanced',np.unique(Train_labels_surprise.squeeze()),Train_labels_surprise.squeeze())
print(class_weight)

i = Input(shape=(20,74))
x = LSTM(64,return_sequences = True)(i)
x = LSTM(32,return_sequences = True)(x)
x = LSTM(32,return_sequences = False)(x)
x = Dense(32,activation='relu')(x)
x = Dense(1,activation='sigmoid')(x)

model = Model(i,x)
print(model.summary())
model.compile('adam','binary_crossentropy',metrics=['accuracy'])

es = EarlyStopping(monitor='val_acc',mode='max' ,patience=5, min_delta=0.0001,verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_acc', factor=0.2,patience=2,min_lr=0.00001)
model.fit(X_train,Train_labels_surprise,512,epochs=100,validation_split=0.1,callbacks=[es,reduce_lr],
          class_weight=dict(enumerate(class_weight)))


y_pred = (model.predict(X_test)>0.5).astype("float")
y_true = Test_labels_surprise
cm = confusion_matrix(y_true,y_pred)

p = precision_score(y_true,y_pred)
a = accuracy_score(y_true,y_pred)
r = recall_score(y_true,y_pred)
f = f1_score(y_true,y_pred)
print(cm)
print("accuracy  :",a)
print("f1 score  :",f)
print("precision :",p)
print("recall    :",r)


TP = cm[1][1]
TN = cm[0][0]
P = Test_labels_surprise.sum()
N = 4832-P
wa = ((TP*N/P) + TN)/(0.02*N)
print("WA        :",wa)
print(classification_report(y_true,y_pred))
model.save("audio_surprise.h5")
# Out:
# [0.55689103 4.8943662 ]
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         (None, 20, 74)            0
# _________________________________________________________________
# lstm_16 (LSTM)               (None, 20, 64)            35584
# _________________________________________________________________
# lstm_17 (LSTM)               (None, 20, 32)            12416
# _________________________________________________________________
# lstm_18 (LSTM)               (None, 32)                8320
# _________________________________________________________________
# dense_14 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 57,409
# Trainable params: 57,409
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 13761 samples, validate on 1529 samples
# Epoch 1/100
# 13761/13761 [==============================] - 14s 1ms/step - loss: 0.6955 - acc: 0.6613 - val_loss: 0.6530 - val_acc: 0.6998
# Epoch 2/100
# 13761/13761 [==============================] - 6s 445us/step - loss: 0.6926 - acc: 0.6473 - val_loss: 0.6520 - val_acc: 0.7057
# Epoch 3/100
# 13761/13761 [==============================] - 5s 365us/step - loss: 0.6920 - acc: 0.5792 - val_loss: 0.6560 - val_acc: 0.5252
# Epoch 4/100
# 13761/13761 [==============================] - 5s 364us/step - loss: 0.6923 - acc: 0.5458 - val_loss: 0.6529 - val_acc: 0.7050
# Epoch 5/100
# 13761/13761 [==============================] - 5s 368us/step - loss: 0.6906 - acc: 0.6559 - val_loss: 0.6530 - val_acc: 0.7050
# Epoch 6/100
# 13761/13761 [==============================] - 5s 362us/step - loss: 0.6903 - acc: 0.6556 - val_loss: 0.6530 - val_acc: 0.7057
# Epoch 7/100
# 13761/13761 [==============================] - 6s 439us/step - loss: 0.6897 - acc: 0.6552 - val_loss: 0.6535 - val_acc: 0.7050
# Epoch 00007: early stopping
# [[2849 1504]
#  [ 277  202]]
# accuracy  : 0.6314155629139073
# f1 score  : 0.1848970251716247
# precision : 0.11840562719812427
# recall    : 0.42171189979123175
# WA        : 53.81015276580784
#               precision    recall  f1-score   support
#
#            0       0.91      0.65      0.76      4353
#            1       0.12      0.42      0.18       479
#
#     accuracy                           0.63      4832
#    macro avg       0.51      0.54      0.47      4832
# weighted avg       0.83      0.63      0.70      4832

# %%
files.download("audio_happy.h5")
files.download("audio_angry.h5")
files.download("audio_sad.h5")
files.download("audio_fear.h5")
files.download("audio_surprise.h5")
files.download("audio_disgust.h5")
